# %%
from bs4 import BeautifulSoup
import pandas as pd
import re
import matplotlib.pyplot as plt
import seaborn as sns

import nltk
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords
import unicodedata

import constants_prepare as prepare

# %%
df = pd.read_csv('master_list.csv')

# %%
df
# Out:
#                                 repo language  \
# 0                  dockerfile/ubuntu    Shell
# 1                   boxcutter/ubuntu    Shell
# 2        wszqkzqk/deepin-wine-ubuntu        C
# 3     fcwu/docker-ubuntu-vnc-desktop     HTML
# 4                docker-32bit/ubuntu    Shell
# ...                              ...      ...
# 3295        gmas/home-router-ansible     Ruby
# 3296                  Voltasalt/tial    Shell
# 3297           Caesim404/sikulix-git    Shell
# 3298          danboid/ZALARM-install      NaN
# 3299               BiteDasher/pacadd    Shell
#
#                                         readme_contents  distro
# 0     ## Ubuntu Dockerfile\n\n\nThis repository cont...  ubuntu
# 1     # Packer templates for Ubuntu written in legac...  ubuntu
# 2     # Deepin wine for Ubuntu and Debian\n\n## 一、项目...  ubuntu
# 3     # docker-ubuntu-vnc-desktop\n\n[![Docker Pulls...  ubuntu
# 4     ubuntu\n======\n\nBuild a docker image for ubu...  ubuntu
# ...                                                 ...     ...
# 3295  # home-router-ansible\nAnsible scripts for set...    arch
# 3296      # tial\nTwitch Installs Arch Linux: Scripts\n    arch
# 3297                                                NaN    arch
# 3298  # Installing Arch Linux ARM (ALARM) on the SHA...    arch
# 3299  # pacadd\nA simple tool for managing repositor...    arch
#
# [3300 rows x 4 columns]

# %%
def no_stem_clean_data(text):
    ps = nltk.porter.PorterStemmer()
    stopwords = nltk.corpus.stopwords.words('english') + prepare.ADDITIONAL_STOPWORDS
    text = (unicodedata.normalize('NFKD', text)
             .encode('ascii', 'ignore')
             .decode('utf-8', 'ignore')
             .lower())
    words = re.sub(r'[\(<\"]?http.*[\)>\"\s]', ' ', text).split()
    words = [re.sub(r'[^\w\s]', '', text) for text in words]
    try:
        while True:
            words.remove('')
    except ValueError:
        pass
    
    return [word for word in words if word not in stopwords]

# %%
df = df.dropna().reset_index().drop(columns= 'index')

# %%
df['cleaned_readme'] = df.readme_contents.apply(no_stem_clean_data)

# %%
df['cleaned_length'] = 0
for i in range(len(df.cleaned_readme)):
    df['cleaned_length'][i] = len(df.cleaned_readme[i])
# Out:
# /var/folders/r6/g880v64s6vj401drwcc37nf00000gn/T/ipykernel_21452/3436486525.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned_length'][i] = len(df.cleaned_readme[i])

# %%
df
# Out:
#                                        repo language  \
# 0                         dockerfile/ubuntu    Shell
# 1                          boxcutter/ubuntu    Shell
# 2               wszqkzqk/deepin-wine-ubuntu        C
# 3            fcwu/docker-ubuntu-vnc-desktop     HTML
# 4                       docker-32bit/ubuntu    Shell
# ...                                     ...      ...
# 2800                         thatch45/varch   Python
# 2801  archclassroom/archclassroom.github.io     HTML
# 2802               gmas/home-router-ansible     Ruby
# 2803                         Voltasalt/tial    Shell
# 2804                      BiteDasher/pacadd    Shell
#
#                                         readme_contents  distro  \
# 0     ## Ubuntu Dockerfile\n\n\nThis repository cont...  ubuntu
# 1     # Packer templates for Ubuntu written in legac...  ubuntu
# 2     # Deepin wine for Ubuntu and Debian\n\n## 一、项目...  ubuntu
# 3     # docker-ubuntu-vnc-desktop\n\n[![Docker Pulls...  ubuntu
# 4     ubuntu\n======\n\nBuild a docker image for ubu...  ubuntu
# ...                                                 ...     ...
# 2800  ==Why Do We Need Varch?==\nThe use of virtuali...    arch
# 2801  # archclassroom.github.io\nArch Linux Classroo...    arch
# 2802  # home-router-ansible\nAnsible scripts for set...    arch
# 2803      # tial\nTwitch Installs Arch Linux: Scripts\n    arch
# 2804  # pacadd\nA simple tool for managing repositor...    arch
#
#                                          cleaned_readme  cleaned_length
# 0     [dockerfile, repository, contains, dockerfile,...              29
# 1     [packer, templates, written, legacy, json, ove...             515
# 2     [deepin, wine, deepinwine, ubuntudebian, deepi...             155
# 3     [dockerubuntuvncdesktop, docker, pulls, docker...             416
# 4     [build, docker, image, i386, run, buildimagesh...              12
# ...                                                 ...             ...
# 2800  [need, varch, use, virtualization, rapidly, ex...             393
# 2801        [archclassroomgithubio, classroom, website]               3
# 2802  [homerouteransible, ansible, scripts, setting,...              18
# 2803                  [tial, twitch, installs, scripts]               4
# 2804  [pacadd, simple, tool, managing, repositories,...             219
#
# [2805 rows x 6 columns]

# %% [markdown]
# # Looking at value counts of all words prior to stemming

# %%
corpus_list = []
for entry in range(len(df.readme_contents)):
    corpus_list.extend(df.cleaned_readme[entry])
corpus = pd.Series(corpus_list)
corpus.describe()
# Out:
# count      971452
# unique      94937
# top       install
# freq         8651
# dtype: object

# %% [markdown]
# Look at frequency of words in languages next

# %% [markdown]
# # Exploring Overall Data

# %%
df.cleaned_length.describe()
# Out:
# count     2805.000000
# mean       346.328699
# std        814.688050
# min          0.000000
# 25%         57.000000
# 50%        150.000000
# 75%        348.000000
# max      22148.000000
# Name: cleaned_length, dtype: float64

# %% [markdown]
# # Looking at top word percentage per language
# Top 3 languages are shell, python, and c

# %%
top_1000 = corpus.value_counts().sort_values(ascending=False).head(5000)

# %%
shell = df.query('language == "Shell"').reset_index()
python = df.query('language == "Python"').reset_index()
c_lang = df.query('language == "C"').reset_index()
other_lang = df.query('language != "Shell" & language != "Python" & language != "C"').reset_index()

# %%
len(shell) + len(python) + len(c_lang) + len(other_lang)
# Out:
# 2805

# %%
shell_corpus_list = []
for entry in range(len(shell)):
    shell_corpus_list.extend(shell.cleaned_readme[entry])
shell_corpus = pd.Series(shell_corpus_list)
shell_corpus.describe()
# Out:
# count      516384
# unique      54972
# top       install
# freq         5534
# dtype: object

# %%
python_corpus_list = []
for entry in range(len(python)):
    python_corpus_list.extend(python.cleaned_readme[entry])
python_corpus = pd.Series(python_corpus_list)
python_corpus.describe()
# Out:
# count      110949
# unique      15950
# top       install
# freq          980
# dtype: object

# %%
c_corpus_list = []
for entry in range(len(c_lang)):
    c_corpus_list.extend(c_lang.cleaned_readme[entry])
c_corpus = pd.Series(c_corpus_list)
c_corpus.describe()
# Out:
# count      73730
# unique     11446
# top       kernel
# freq        1068
# dtype: object

# %%
other_lang_corpus_list = []
for entry in range(len(other_lang)):
    other_lang_corpus_list.extend(other_lang.cleaned_readme[entry])
other_lang_corpus = pd.Series(other_lang_corpus_list)
other_lang_corpus.describe()
# Out:
# count      270389
# unique      37566
# top       install
# freq         1769
# dtype: object

# %%
top_1000.head().index
# Out:
# Index(['install', 'use', 'run', 'file', 'script'], dtype='object')

# %%
totals = []
for i in top_1000.index:
    total = 0
    for j in range(len(shell)):
        if i in shell.cleaned_readme[j]:
            total +=1
    totals.append(round(total /len(shell), 4))
    print("Shell" + i)
shell_percentages = totals


totals = []
for i in top_1000.index:
    total = 0
    for j in range(len(python)):
        if i in python.cleaned_readme[j]:
            total +=1
    totals.append(round(total /len(python), 4))
    print("Python" + i)
python_percentages = totals

totals = []
for i in top_1000.index:
    total = 0
    for j in range(len(c_lang)):
        if i in c_lang.cleaned_readme[j]:
            total +=1
    totals.append(round(total /len(c_lang), 4))
    print("C" + i)
c_percentages = totals

totals = []
for i in top_1000.index:
    total = 0
    for j in range(len(other_lang)):
        if i in other_lang.cleaned_readme[j]:
            total +=1
    totals.append(round(total /len(other_lang), 4))
    print("Others" + i)
other_lang_percentages = totals
# Out:
# Shellinstall
# Shelluse
# Shellrun
# Shellfile
# Shellscript
# Shelldefault
# Shellbuild
# Shellsystem
# Shellusing
# Shelldocker
# Shellmake
# Shellkernel
# Shellbash
# Shellpackages
# Shell1
# Shellversion
# Shellpackage
# Shellimage
# Shellset
# Shellserver
# Shellfiles
# Shellconfiguration
# Shelluser
# Shellinstallation
# Shell2
# Shellupdate
# Shellalso
# Shellsee
# Shellneed
# Shellcommand
# Shellused
# Shelladd
# Shellfollowing
# Shelldirectory
# Shellnew
# Shelle
# Shellwant
# Shellname
# Shellcreate
# Shellinstalled
# Shell3
# Shellsupport
# Shellp
# Shellrunning
# Shellone
# Shellenvironment
# Shellexample
# Shellrepository
# Shelllike
# Shellboot
# Shellcd
# Shellplease
# Shellmay
# Shellstart
# Shellde
# Shellsource
# Shellwork
# Shelldownload
# Shellavailable
# Shellcontainer
# Shellshell
# Shellensure
# Shelllist
# Shelltime
# Shellget
# Shellapt
# Shellscripts
# Shellx
# Shellproject
# Shellnote
# Shelllicense
# Shellconfig
# Shellssh
# Shellsoftware
# Shellsh
# Shellfirst
# Shellcode
# Shellsetup
# Shellchange
# Shellkey
# Shell4
# Shellpassword
# Shellclone
# Shellservice
# Shellvia
# Shellpacman
# Shelloptions
# Shellcheck
# Shellhost
# Shellos
# Shell0
# Shelldesktop
# Shelloption
# Shellnetwork
# Shellenable
# Shellvideo
# Shelldevice
# Shellwithout
# Shelllibrary
# Shellconfigure
# Shellbased
# Shellc
# Shellwindows
# Shellinformation
# Shelldata
# Shellpython
# Shelleg
# Shelltype
# Shellusage
# Shellautomated
# Shelllatest
# Shelldont
# Shelloptional
# Shellrequired
# Shellmachine
# Shelltr
# Shellline
# Shellimages
# Shellsupported
# Shellusers
# Shellhelp
# Shellpath
# Shellopen
# Shellaccess
# Shellvariables
# Shellmode
# Shellusb
# Shellrepo
# Shellpartition
# Shellcopy
# Shellrelease
# Shelltrue
# Shelltest
# Shellgithub
# Shellfind
# Shellwget
# Shellsettings
# Shellcommands
# Shell5
# Shelldependencies
# Shellmust
# Shellsure
# Shellchanges
# Shellprocess
# Shellfalse
# Shellautomatically
# Shelloutput
# Shellvalue
# Shellport
# Shelltdtd
# Shellf
# Shelltools
# Shellremove
# Shellansible
# Shelllocal
# Shelliso
# Shelldocumentation
# Shellbuilding
# Shellterminal
# Shellv
# Shellinterface
# Shelllearning
# Shellweb
# Shellgo
# Shellstatus
# Shellinstaller
# Shellread
# Shellvagrant
# Shelladded
# Shellinstalling
# Shellchmod
# Shellvirtual
# Shelladdress
# Shellbase
# Shellcustom
# Shellcurrent
# Shellvariable
# Shellnumber
# Shellway
# Shellecho
# Shellfound
# Shellintelr
# Shellaur
# Shelltool
# Shellconfigured
# Shelldisk
# Shellip
# Shellfolder
# Shellapplication
# Shelluses
# Shelldone
# Shellsize
# Shellissue
# Shelllts
# Shelllink
# Shellsrc
# Shellreboot
# Shellbr
# Shelldifferent
# Shellcase
# Shellversions
# Shellspecific
# Shelletc
# Shell10
# Shell8
# Shellsystemctl
# Shellwould
# Shellpull
# Shell7
# Shellmath
# Shellfeatures
# Shellrole
# Shellsystems
# Shellfull
# Shellneeded
# Shellclient
# Shellenabled
# Shellmemory
# Shellcreated
# Shelldatabase
# Shelldisable
# Shellallow
# Shelllogin
# Shellprogram
# Shellorder
# Shellpossible
# Shellinstead
# Shellcurl
# Shelldevelopment
# Shellapplications
# Shellbuilt
# Shellstring
# Shellcontains
# Shellsetting
# Shellfree
# Shellissues
# Shelledit
# Shellofficial
# Shellwell
# Shellmanager
# Shellsection
# Shellalready
# Shellhref
# Shellworking
# Shellpublic
# Shellwindow
# Shellnginx
# Shellsimple
# Shelladditional
# Shellcontrol
# Shellkeys
# Shellscreen
# Shelldetails
# Shellmain
# Shelldeb
# Shellprovided
# Shellsecurity
# Shellhome
# Shellmultiple
# Shellupgrade
# Shellformat
# Shellgroup
# Shelltry
# Shellmodule
# Shellinclude
# Shellcurrently
# Shellr
# Shellinstructions
# Shellservices
# Shell6
# Shelltext
# Shelllog
# Shellmount
# Shelltesting
# Shellmany
# Shelltarget
# Shellinfo
# Shellshow
# Shellsince
# Shellneeds
# Shelllook
# Shelleven
# Shelltake
# Shellgenerate
# Shelleither
# Shellexport
# Shelldescription
# Shellmodules
# Shelltheme
# Shellchroot
# Shellnetworks
# Shelltwo
# Shellmysql
# Shellupdates
# Shellworks
# Shellable
# Shellphp
# Shelluseful
# Shellfix
# Shellpage
# Shellerror
# Shellincluding
# Shelldistribution
# Shellpi
# Shellgeneral
# Shellprovide
# Shellcard
# Shellconsole
# Shellback
# Shellstill
# Shellid
# Shellvalues
# Shellstep
# Shellfunction
# Shellinside
# Shelldisplay
# Shellsteps
# Shellexecute
# Shellconnect
# Shelldriver
# Shellstable
# Shellbox
# Shelltested
# Shellneural
# Shellrestart
# Shellcp
# Shellyes
# Shellrequirements
# Shellselect
# Shellfollow
# Shellhardware
# Shellmanual
# Shellrm
# Shellbranch
# Shelldefined
# Shellhosts
# Shellbinary
# Shellprovides
# Shellend
# Shellmenu
# Shellenter
# Shellrecommended
# Shelll
# Shellincluded
# Shellmodify
# Shellsystemd
# Shellhowever
# Shelleasy
# Shelldirectly
# Shellyoull
# Shellevery
# Shellpermissions
# Shellnode
# Shelldoesnt
# Shellpara
# Shellsingle
# Shellmanually
# Shelllocation
# Shellguide
# Shellmight
# Shellapp
# Shellrequires
# Shellgnulinux
# Shellzabbix
# Shellmaster
# Shellvim
# Shellspace
# Shellallows
# Shell2017
# Shellmanagement
# Shellexamples
# Shellusername
# Shellspecified
# Shellu
# Shellinstalls
# Shell9
# Shellpoint
# Shelleverything
# Shelldevices
# Shellspecify
# Shellgnome
# Shellkeep
# Shellthings
# Shellcould
# Shellsomething
# Shellthanks
# Shelln
# Shellchoose
# Shellbuilds
# Shellright
# Shellmuch
# Shellcompile
# Shell400
# Shellclean
# Shellvm
# Shellnotes
# Shellpart
# Shellmkdir
# Shellmade
# Shell1804
# Shellknow
# Shellyoure
# Shellalways
# Shellcentos
# Shellnecessary
# Shellsupports
# Shellremote
# Shellsimply
# Shellinternet
# Shellarchitecture
# Shellwrite
# Shellgenerated
# Shellcache
# Shellopenvpn
# Shell20
# Shellgnu
# Shellurl
# Shellaligncenter
# Shellanother
# Shellconnection
# Shellraspberry
# Shelldefine
# Shellcopyright
# Shellbackup
# Shelldefaults
# Shelluboot
# Shellvirtualbox
# Shellrepositories
# Shellapache
# Shellstop
# Shellimportant
# Shellus
# Shellkeyboard
# Shellgrub
# Shellcomplete
# Shellparameters
# Shellbug
# Shellcontents
# Shellexit
# Shelltests
# Shellstarted
# Shellstandard
# Shellcolor
# Shellh
# Shellcloud
# Shelltable
# Shellfunctions
# Shellhostname
# Shellwarning
# Shell2018
# Shellda
# Shelldrivers
# Shellfeature
# Shell11
# Shell2004
# Shellprofile
# Shellcreating
# Shellb
# Shellarm
# Shellservers
# Shellfilesystem
# Shellplaybook
# Shellsearch
# Shellinstance
# Shellbest
# Shelltop
# Shellpatch
# Shelldrive
# Shelldeep
# Shelldelete
# Shellnext
# Shellinit
# Shelldisabled
# Shellcommunity
# Shelldotfiles
# Shellcpu
# Shelldns
# Shellswap
# Shellstartup
# Shellbetter
# Shellicon
# Shellmeans
# Shellnvidia
# Shellotherwise
# Shellparameter
# Shellproblem
# Shellupdated
# Shellrequest
# Shellcontainers
# Shellold
# Shelltag
# Shellufw
# Shellproblems
# Shellcalled
# Shellclick
# Shellreleases
# Shellcore
# Shellseveral
# Shellstorage
# Shellmac
# Shelllines
# Shellproxy
# Shellmnt
# Shellsecure
# Shelllive
# Shellstate
# Shelladding
# Shelldaemon
# Shelloperating
# Shellpatches
# Shellapi
# Shelldebug
# Shellwiki
# Shelltemplate
# Shellexisting
# Shelldockerfile
# Shellpower
# Shellreplace
# Shellrequests
# Shellpartitions
# Shellwifi
# Shellwithin
# Shellaccount
# Shellgood
# Shellput
# Shellreport
# Shellbrowser
# Shellapply
# Shellsd
# Shellfont
# Shelllater
# Shell500
# Shell300
# Shellplugin
# Shelldpkg
# Shellextra
# Shellsources
# Shellincludes
# Shellgoogle
# Shellandroid
# Shellbasic
# Shellruns
# Shelllot
# Shellzsh
# Shellrules
# Shellcomo
# Shellmacos
# Shellload
# Shellcommit
# Shellroles
# Shellrequire
# Shelldhcp
# Shellplace
# Shellpip
# Shellgiven
# Shelldirectories
# Shellchanged
# Shellpresent
# Shelldate
# Shell7x
# Shellminimal
# Shellicons
# Shellsave
# Shellmirror
# Shell1604
# Shelllevel
# Shellapps
# Shellmit
# Shell100
# Shellstarting
# Shellpackaging
# Shellperformance
# Shell233
# Shellcommon
# Shellcontent
# Shelloriginal
# Shellfirewall
# Shellcorrect
# Shelleasily
# Shellram
# Shelldistributions
# Shellanything
# Shellcomputer
# Shellmachines
# Shellvarious
# Shelllaunch
# Shellswitch
# Shelllogs
# Shell64bit
# Shellmessage
# Shellsed
# Shellemail
# Shellgetting
# Shellresult
# Shellpacker
# Shellnamed
# Shellgive
# Shellmedia
# Shellprograms
# Shelltar
# Shelllast
# Shellcat
# Shellsend
# Shellconfiguracao
# Shell600
# Shellie
# Shellmethod
# Shellplatform
# Shellparticular
# Shellcontroller
# Shellexecutable
# Shellexec
# Shellul
# Shellsession
# Shellprint
# Shellyet
# Shellleast
# Shellvolume
# Shellsets
# Shelllanguage
# Shellarguments
# Shellremoved
# Shellamazon
# Shellvnc
# Shellspeed
# Shellrelated
# Shellknown
# Shellbugs
# Shellcannot
# Shelllibraries
# Shelljava
# Shellwhether
# Shellmanage
# Shelltree
# Shellautomatic
# Shellcluster
# Shellupstream
# Shellyaml
# Shellspecial
# Shelltasks
# Shellwritten
# Shellfirefox
# Shellsimilar
# Shellbios
# Shellprivate
# Shellmodel
# Shellnormal
# Shellaudio
# Shelllong
# Shellcontain
# Shellscored
# Shellscreenshot
# Shellbackground
# Shellwelcome
# Shellarchive
# Shellq
# Shellgui
# Shelllonger
# Shellports
# Shellsmall
# Shelllayout
# Shellauto
# Shellsecond
# Shellg
# Shellstore
# Shellprobably
# Shelllinks
# Shellaligncentersupported
# Shellglobal
# Shellnames
# Shellpkgbuild
# Shellexecuted
# Shelldomain
# Shellflash
# Shelltags
# Shellrecommend
# Shellnesse
# Shellquick
# Shell1404
# Shellpass
# Shellper
# Shellprojects
# Shellgpg
# Shellchrome
# Shellpress
# Shellfirmware
# Shell12
# Shellusually
# Shellim
# Shellfork
# Shellinput
# Shellmaking
# Shellpurpose
# Shellnone
# Shelldownloaded
# Shellpolicy
# Shell30
# Shellwont
# Shellmakes
# Shellqemu
# Shellpeople
# Shellci
# Shellruby
# Shellbit
# Shelldev
# Shellless
# Shelldue
# Shellgrep
# Shellerrors
# Shellaula
# Shellnano
# Shellinitial
# Shellaction
# Shelldeploy
# Shellprocesses
# Shelllet
# Shellleft
# Shellprompt
# Shellreference
# Shelllocated
# Shellprevious
# Shellenv
# Shellque
# Shellboard
# Shellopenstack
# Shellcontaining
# Shellfast
# Shellentry
# Shellnodes
# Shellwish
# Shellcli
# Shelljunest
# Shellflags
# Shellive
# Shellexist
# Shellextension
# Shellssl
# Shellbtrfs
# Shellauthentication
# Shellintel
# Shellinstallsh
# Shellkernels
# Shellcreates
# Shellvpn
# Shellnotice
# Shellnewer
# Shellcertificate
# Shellandor
# Shelltab
# Shellreleased
# Shellagent
# Shellfedora
# Shelllocally
# Shellaround
# Shellexternal
# Shellmonitor
# Shellactions
# Shellquestions
# Shellcis
# Shellwireguard
# Shelluninstall
# Shelltmp
# Shellregular
# Shellum
# Shelli3
# Shellready
# Shellfully
# Shellhub
# Shelllets
# Shellcall
# Shellefi
# Shellseparate
# Shellreally
# Shellconfigurations
# Shellreal
# Shellamd64
# Shellfollows
# Shellencryption
# Shellcontributing
# Shelltodo
# Shellgcc
# Shelllooking
# Shellfeel
# Shelleditor
# Shell24
# Shellem
# Shellgpu
# Shellstored
# Shelltraining
# Shellcompiling
# Shellproperly
# Shellshared
# Shellimport
# Shelltakes
# Shellln
# Shell_
# Shelllicensed
# Shellseconds
# Shellmove
# Shelldistributed
# Shellmap
# Shellfonts
# Shellbluetooth
# Shellalt
# Shellunit
# Shellpush
# Shellextract
# Shellwebsite
# Shellscreenshots
# Shellbinaries
# Shellbooting
# Shellchannel
# Shellresources
# Shellreason
# Shellreadme
# Shelldevelopers
# Shellunless
# Shellwine
# Shellminutes
# Shellplugins
# Shelldevops
# Shellview
# Shellbar
# Shellalias
# Shelldownloads
# Shellpost
# Shellblock
# Shelltcp
# Shellconnections
# Shelldefines
# Shelldependency
# Shellauthor
# Shelldepending
# Shellflag
# Shellcurso
# Shelloverride
# Shellactive
# Shelluefi
# Shellrepos
# Shellcomponents
# Shellfailed
# Shellperform
# Shellipv6
# Shellalong
# Shellthats
# Shellyay
# Shellcustomize
# Shellnever
# Shellavoid
# Shellmakepkg
# Shell16
# Shellmail
# Shellstack
# Shellothers
# Shellrefer
# Shellguest
# Shellthemes
# Shellcompiled
# Shellactually
# Shellstructure
# Shellupdating
# Shellappropriate
# Shellforce
# Shellsnapshot
# Shellmatch
# Shell32
# Shellempty
# Shellworkspace
# Shellresults
# Shellsite
# Shellsync
# Shellnoconfirm
# Shellsolution
# Shellxfce
# Shelltell
# Shellmirrors
# Shellcompression
# Shelllimited
# Shellconsider
# Shellreading
# Shellgoing
# Shellverbose
# Shellargument
# Shellfinally
# Shellmounted
# Shellstatic
# Shellalternatively
# Shelltimeout
# Shell15
# Shellexists
# Shell13
# Shellx86_64
# Shellaws
# Shellpermission
# Shelliptables
# Shellchoice
# Shellcompatible
# Shellday
# Shellinstalar
# Shellapplied
# Shelltor
# Shellchown
# Shellverify
# Shellmessages
# Shellstuff
# Shellstarts
# Shellgraph
# Shellansibleplaybook
# Shellprotocol
# Shellsound
# Shellinternal
# Shellsuper
# Shellcorrectly
# Shellbuildsh
# Shelladversarial
# Shellsometimes
# Shelladmin
# Shellthough
# Shellbootloader
# Shellshare
# Shellext4
# Shelldescribed
# Shellproduction
# Shellbytes
# Shellprivileges
# Shellchecks
# Shellsample
# Shellman
# Shelldesigned
# Shellclients
# Shellresolution
# Shellcant
# Shellterms
# Shellrootroot
# Shellcompletely
# Shellintegration
# Shellchangelog
# Shellw
# Shellserial
# Shellenough
# Shellcompilation
# Shellwireless
# Shellethernet
# Shellturn
# Shellelse
# Shelladdaptrepository
# Shellencrypted
# Shellhigh
# Shell333
# Shelladds
# Shelladvanced
# Shellconfiguring
# Shellclass
# Shell667
# Shellcases
# Shelldir
# Shellgraphics
# Shellwait
# Shellcompatibility
# Shellfixed
# Shellsu
# Shell22
# Shellruntime
# Shellbutton
# Shellcomes
# Shellrather
# Shellpersonal
# Shelltask
# Shellcheckout
# Shellcontact
# Shellhard
# Shellrandom
# Shellreset
# Shellhelper
# Shellmakefile
# Shellcontinue
# Shellgeneration
# Shellvisual
# Shelldesired
# Shellxx
# Shellworld
# Shellnodejs
# Shelleasier
# Shellla
# Shellenables
# Shellarchitectures
# Shellprefer
# Shellunity
# Shell2004x
# Shellgroups
# Shellexperimental
# Shell32bit
# Shellask
# Shell80
# Shellprevent
# Shellpython3
# Shellenjoy
# Shellbootstrap
# Shelltoken
# Shellfuture
# Shellutility
# Shelltdstringtd
# Shellcertificates
# Shellyoutubedl
# Shellonline
# Shelldepends
# Shellsnap
# Shellexperience
# Shellsr
# Shelllikely
# Shellchromium
# Shellthree
# Shell167
# Shelltouch
# Shelllearn
# Shellsuite
# Shellones
# Shelltimezone
# Shellremember
# Shellwhole
# Shellwrong
# Shellredis
# Shellaudit
# Shellwriting
# Shelljson
# Shellmissing
# Shellcontributors
# Shellls
# Shellreinforcement
# Shellselected
# Shellhandle
# Shellupload
# Shelloverview
# Shellenvironments
# Shellframework
# Shellmodified
# Shellgreat
# Shellloaded
# Shellchecking
# Shellexpected
# Shellwhatever
# Shellcompletion
# Shellnpm
# Shellconnected
# Shelltitle
# Shellengine
# Shellmouse
# Shellpages
# Shelloptionally
# Shellluks
# Shellbreak
# Shellkubernetes
# Shellbind
# Shellfixes
# Shellui
# Shellmodels
# Shelledition
# Shellvmware
# Shelldockercompose
# Shellrule
# Shellcomment
# Shellpuppet
# Shelldeveloper
# Shellwarranty
# Shellreturn
# Shelloperation
# Shelllogging
# Shellok
# Shellunix
# Shellsocket
# Shellshows
# Shellextensions
# Shellcorresponding
# Shellaligncenternot
# Shellnetworking
# Shellintended
# Shellcause
# Shellcollection
# Shellmaximum
# Shellsyntax
# Shell14
# Shellprofiles
# Shellrootfs
# Shelleof
# Shellimplementation
# Shellolder
# Shelldebugging
# Shellfunctionality
# Shelladdresses
# Shellbackend
# Shellthing
# Shelllisted
# Shelldiv
# Shelllaptop
# Shellstretch
# Shellprerequisites
# Shelltd
# Shelljessie
# Shelltherefore
# Shellisnt
# Shellbenchmark
# Shellcertain
# Shellactual
# Shellskip
# Shellcredits
# Shellbuster
# Shellexecution
# Shelldetection
# Shelltmpfs
# Shellzip
# Shellxmonad
# Shellqt
# Shellpublished
# Shelldd
# Shellidea
# Shellcompute
# Shellxorg
# Shelllocalhost
# Shellntp
# Shell21
# Shellchanging
# Shell1804x
# Shellgoes
# Shelllarge
# Shelloracle
# Shellalternative
# Shelljob
# Shellservidor
# Shelltomcat
# Shellaccording
# Shellgraphical
# Shellsay
# Shellred
# Shellnormally
# Shellbashrc
# Shellmb
# Shellppa
# Shelloperations
# Shellk
# Shellcontribute
# Shellproper
# Shelllooks
# Shellmicrosoft
# Shellentries
# Shellcreation
# Shellpanel
# Shellshutdown
# Shellstyle
# Shellexecuting
# Shellheader
# Shellel
# Shellcome
# Shellgets
# Shellhistory
# Shellen
# Shellcompiler
# Shellprepare
# Shellpc
# Shellinteractive
# Shellkde
# Shellhash
# Shellminimum
# Shelldocument
# Shellfolders
# Shellpassed
# Shellstick
# Shelltutorial
# Shell__
# Shellfaster
# Shelllauncher
# Shellconvert
# Shelldetailed
# Shelltoptableofcontents
# Shellnetworkmanager
# Shellstudio
# Shellprogress
# Shellopenssl
# Shellutilizado
# Shellfilename
# Shellj
# Shelllimit
# Shellpostgresql
# Shelldeployment
# Shellremoving
# Shellignore
# Shellactivate
# Shellentire
# Shellexcept
# Shelltls
# Shelltargets
# Shellphysical
# Shellheadless
# Shellvps
# Shellnative
# Shellinterfaces
# Shellipv4
# Shellmaintained
# Shellnice
# Shellcron
# Shellplatforms
# Shell2019
# Shellunzip
# Shellmatching
# Shelloptimization
# Shellcopied
# Shellallowed
# Shellform
# Shelltypes
# Shelltimes
# Shellkvm
# Shelldaily
# Shelllock
# Shellprovider
# Shellgtk
# Shellbinbash
# Shellzfs
# Shelldownloading
# Shellheavy_check_mark
# Shellkind
# Shellimprove
# Shellyoutube
# Shellgb
# Shellquickly
# Shellpaths
# Shellrecovery
# Shellarquivo
# Shellways
# Shellthus
# Shellbecome
# Shellcuda
# Shellcourse
# Shelltotal
# Shellquality
# Shellrest
# Shelllvm
# Shellforget
# Shelljenkins
# Shellbitcoin
# Shellauthors
# Shellgratuito
# Shellresulting
# Shellefficient
# Shellrecent
# Shellaura
# Shellredhat
# Shellrf
# Shellfresh
# Shellwallpaper
# Shelldocs
# Shelllittle
# Shellscratch
# Shelltee
# Shellvalid
# Shelloften
# Shellarquivos
# Shelllayer
# Shelladdition
# Shellinitramfs
# Shelltda
# Shellsetuppy
# Shellexactly
# Shellsnapshots
# Shellmaintainer
# Shelltheres
# Shellgeneric
# Shellprivileged
# Shelllocale
# Shelleth0
# Shell6x
# Shellrebuild
# Shellprocedimentos
# Shelllightdm
# Shelluma
# Shellunderstand
# Shellproot
# Shellpurge
# Shelldos
# Shelldebootstrap
# Shellpublish
# Shell___
# Shellfinal
# Shellconfigs
# Shellvou
# Shellrisk
# Shellfails
# Shelltypically
# Shelllow
# Shelldetect
# Shellautomate
# Shellopenssh
# Shellfail
# Shelldistros
# Shellhigher
# Shellpreferences
# Shell567
# Shellsign
# Shelltraffic
# Shellrelevant
# Shellediting
# Shellshort
# Shellutilities
# Shellleave
# Shellyouve
# Shellknowledge
# Shellmajor
# Shellcomments
# Shell64
# Shell40
# Shellintroduction
# Shellindex
# Shellpulseaudio
# Shelltrusted
# Shelltemplates
# Shellmolecule
# Shellnumbers
# Shellprocedure
# Shellmv
# Shellqo
# Shellespecially
# Shellprefix
# Shellprimary
# Shelldesign
# Shelldetected
# Shellmethods
# Shellbootable
# Shellwsl
# Shellini
# Shelldynamic
# Shellteam
# Shellhtml
# Shellsuggestions
# Shellfrontend
# Shellreports
# Shellheaders
# Shellcopying
# Shellapproach
# Shellrestore
# Shellobject
# Shellconfigures
# Shellbad
# Shellbus
# Shellassociated
# Shellswift
# Shellblog
# Shellarm64
# Shellparts
# Shelltogether
# Shellwhats
# Shellio
# Shellcontext
# Shellplay
# Shellloading
# Shellshortcuts
# Shellattention
# Shelldeveloped
# Shelleffect
# Shellpasswd
# Shellarea
# Shellmounting
# Shellcassandra
# Shellvisit
# Shellreload
# Shellloss
# Shellproviding
# Shelltroubleshooting
# Shellsubdirectory
# Shelllists
# Shelltransfer
# Shellimplied
# Shellzero
# Shellalgorithm
# Shelljoin
# Shellpoints
# Shellhold
# Shellplus
# Shellplaced
# Shellcolors
# Shellse
# Shellcommandline
# Shellstage
# Shellrede
# Shelldebianubuntu
# Shelllogo
# Shellupgrading
# Shelldisplayed
# Shellmapping
# Shellvirtualization
# Shellthink
# Shelllightweight
# Shellpretty
# Shellbuildessential
# Shell8080
# Shellmostrando
# Shellsignature
# Shellability
# Shellpolybar
# Shellaccept
# Shellprovision
# Shellhelps
# Shelldeepin
# Shellbattery
# Shellseparated
# Shelltarball
# Shellgives
# Shell27
# Shelli386
# Shellencrypt
# Shellupon
# Shellsdk
# Shellpreferred
# Shellbasicos
# Shellprebuilt
# Shellblocks
# Shelltermux
# Shellpkgbuilds
# Shellkali
# Shellimplemented
# Shellfine
# Shellvolumes
# Shellignored
# Shellami
# Shelluncomment
# Shellfan
# Shellclose
# Shellinitrd
# Shellcopies
# Shellnocheckcertificate
# Shellreplaced
# Shellwheel
# Shelltemporary
# Shellshown
# Shelludp
# Shellou
# Shellnull
# Shellhardening
# Shelltmux
# Shellacross
# Shellboxes
# Shellfeedback
# Shellcustomization
# Shellforward
# Shellinfrastructure
# Shellquite
# Shellmaintenance
# Shellgem
# Shellselection
# Shellbits
# Shellattempt
# Shellsuccessfully
# Shellsecret
# Shellflatpak
# Shellbehavior
# Shellside
# Shellfilesystems
# Shellbasedevel
# Shelltyping
# Shellvs
# Shellcards
# Shellmanaging
# Shelladditionally
# Shelllamp
# Shellregistered
# Shellsuccessful
# Shellcoin
# Shelldump
# Shellcom
# Shellsoon
# Shellgzip
# Shellmanaged
# Shellinventory
# Shellnet
# Shellnfs
# Shellmetadata
# Shellinsert
# Shellproperties
# Shellvideos
# Shellinstances
# Shellcount
# Shellpartitioning
# Shellgoal
# Shellalpine
# Shellint
# Shellfield
# Shellmaintainers
# Shellshortcut
# Shelleks
# Shellmodifications
# Shellwayland
# Shellplaybooks
# Shelllibreoffice
# Shellclear
# Shellallowing
# Shellbehind
# Shellinitialization
# Shellamount
# Shellthird
# Shellmoment
# Shelllifixed
# Shellcrouton
# Shelltutorials
# Shellpurposes
# Shellindividual
# Shellsistema
# Shellgenerating
# Shelltaken
# Shellneovim
# Shellbroken
# Shellreview
# Shellrepresentation
# Shellenabling
# Shelladjust
# Shellalthough
# Shellplan
# Shellformats
# Shellspecifies
# Shellhours
# Shelltravis
# Shellmaintain
# Shellmax
# Shellmint
# Shellbuffer
# Shelldebiancontrol
# Shellbin
# Shelli2c
# Shellcompressed
# Shellmaybe
# Shellcalls
# Shellhook
# Shellmobile
# Shellpreviously
# Shellhappens
# Shellrate
# Shellramdisk
# Shellremoves
# Shellseems
# Shellbig
# Shellverification
# Shellrange
# Shellregarding
# Shelllower
# Shellwrapper
# Shellsubmodule
# Shellaconfmgr
# Shellkitty
# Shellhighly
# Shellbullseye
# Shellviewer
# Shellalmost
# Shellreadonly
# Shell20130712
# Shellsubmit
# Shell50
# Shellassume
# Shellarchwiki
# Shell0118
# Shellmariadb
# Shellbrightness
# Shellraspbian
# Shelldeprecated
# Shellacceleration
# Shellmainline
# Shellfocus
# Shellnand
# Shellsaved
# Shellfaq
# Shellcamera
# Shellupgrades
# Shellconsidered
# Shellaccessible
# Shellmostrar
# Shellgpl
# Shelllisten
# Shelldatabases
# Shellinstalacao
# Shellrobust
# Shelltrying
# Shellconditions
# Shellbuilder
# Shellslow
# Shellx86
# Shellhtop
# Shell1204
# Shellsuitable
# Shellmonitoring
# Shellsigning
# Shellseries
# Shelldb
# Shellexplicitly
# Shellalfresco
# Shellhello
# Shellvirtualenv
# Shellcredentials
# Shellbrew
# Shellsafe
# Shellprior
# Shellna
# Shellhead
# Shelllilo
# Shellrofi
# Shellbottom
# Shellgenerally
# Shellmentioned
# Shellendpoint
# Shellinstallations
# Shellmodern
# Shell733
# Shellhooks
# Shellgenerative
# Shellgateway
# Shellftp
# Shellcare
# Shellproduct
# Shellps
# Shellarray
# Shelldrop
# Shellmerge
# Shellpriority
# Shellincrease
# Shellopenbox
# Shellwanted
# Shell17
# Shellrwrr
# Shelldebops
# Shelldemo
# Shellwatch
# Shellrights
# Shellregister
# Shelldiscord
# Shelltouchpad
# Shellxenial
# Shellbackups
# Shellpasswords
# Shellpdf
# Shellwordpress
# Shellunique
# Shellnothing
# Shellfilter
# Shellclock
# Shellassuming
# Shellcharacters
# Shelldonate
# Shellsensors
# Shellshall
# Shellrelative
# Shelldays
# Shellconf
# Shellvms
# Shellgot
# Shellelasticsearch
# Shellcollected
# Shellcontributions
# Shellfun
# Shellpowershell
# Shellupgraded
# Shell19
# Shelletcfstab
# Shelloverridden
# Shellcharacter
# Shellfakeroot
# Shellrefresh
# Shellresize
# Shellpid
# Shellmeta
# Shelltpm
# Shelldark
# Shelllinked
# Shellresource
# Shellindicator
# Shellpypi
# Shellhope
# Shellcodeblock
# Shellscan
# Shelltweaks
# Shellfetch
# Shellgames
# Shelltransaction
# Shelltrusty
# Shellappimage
# Shellfoundation
# Shelloptimized
# Shellpreview
# Shellimmediately
# Shelldevnull
# Shellevents
# Shelltowards
# Shellh1
# Shellpackets
# Shellbaseimagedocker
# Shellliadded
# Shellsteam
# Shellgpd
# Shelllicenselicense
# Shellenglish
# Shellca
# Shellraw
# Shellhat
# Shellawesome
# Shellpopular
# Shellalternatives
# Shellvars
# Shellmind
# Shellpaypal
# Shellsymbol
# Shellimprovements
# Shellec2
# Shellsymlink
# Shellctrl
# Shellosx
# Shellhappen
# Shellwhenever
# Shelllicenses
# Shellgsettings
# Shellquestion
# Shellslurm
# Shellfinished
# Shellgenerates
# Shellcrontab
# Shellreverse
# Shellfitness
# Shelllight
# Shellappend
# Shellunattended
# Shellreferences
# Shelltracker
# Shellssd
# Shellbeginning
# Shellcomponent
# Shelldedicated
# Shellorigin
# Shell3d
# Shelloutside
# Shelldisables
# Shelldas
# Shellexpect
# Shellsy
# Shellmerchantability
# Shellmemcached
# Shellpro
# Shellunstable
# Shellcompilers
# Shelldrives
# Shellfocal
# Shell18
# Shellproduce
# Shellreasons
# Shellarent
# Shellyoud
# Shellloader
# Shellhavent
# Shellprompted
# Shellmusic
# Shelllegacy
# Shellmeant
# Shellcallback
# Shellworkstation
# Shellsent
# Shellcustomized
# Shelluuid
# Shelloffset
# Shell25
# Shellyum
# Shellsense
# Shellrepresentations
# Shellcomplex
# Shellrsa
# Shelltty
# Shellbasically
# Shellloop
# Shellund
# Shelltweak
# Shellaptly
# Shellanyone
# Shellworkflow
# Shellconnecting
# Shellbranches
# Shell467
# Shellcontinuous
# Shelldirect
# Shellrouter
# Shellnews
# Shelldisabling
# Shellqq
# Shellopening
# Shellpassing
# Shellguides
# Shelllocales
# Shellchromebook
# Shellfront
# Shellprivacy
# Shelles
# Shellplayer
# Shellextracted
# Shellanalysis
# Shellenterprise
# Shellsigned
# Shellitems
# Shellaims
# Shelldetermine
# Shellffmpeg
# Shellanymore
# Shellevent
# Shellxxxxxxxx
# Shellapparmor
# Shellsending
# Shelltrack
# Shellautostart
# Shellnotification
# Shell34
# Shell5x
# Shellthank
# Shellboolean
# Shellmandatory
# Shellopensource
# Shellxrandr
# Shellheres
# Shellusermod
# Shellbauh
# Shellsway
# Shellnewly
# Shellgradient
# Shellsummary
# Shellbooted
# Shellsections
# Shellxournal
# Shellhit
# Shellblack
# Shelldkms
# Shellsort
# Shellsequence
# Shellbundle
# Shellcompleted
# Shelletcpacmanconf
# Shellprocessing
# Shelldisplays
# Shellparted
# Shellcodes
# Shellspotify
# Shellcenter
# Shell200
# Shelldebianbased
# Shellresponsible
# Shelldestination
# Shellincoming
# Shellarmhf
# Shellmailing
# Shellduplicate
# Shellfit
# Shellv2
# Shellforeground
# Shellattacks
# Shellowner
# Shellprogramming
# Shellsensor
# Shellfoo
# Shellfact
# Shellscheme
# Shellproxmox
# Shelllabel
# Shellpkg
# Shellofficially
# Shellsplit
# Shellhosting
# Shellanswer
# Shellbuiltin
# Shelltftp
# Shell512
# Shellkill
# Shellpostfix
# Shellsyslog
# Shelladdons
# Shellvalidation
# Shellumount
# Shellexecutar
# Shellbionic
# Shellfpm
# Shellpool
# Shelltwitter
# Shellearlier
# Shellspecification
# Shellcontrols
# Shellrepositorio
# Shelldepend
# Shellmatches
# Shellcores
# Shellhandling
# Shellarchinstall
# Shellforum
# Shellcmake
# Shellperformed
# Shellx64
# Shellyaourt
# Shellaccounts
# Shellnosso
# Shellgdb
# Shellmate
# Shellxfce4
# Shelldialog
# Shellgame
# Shellscope
# Shellpreseed
# Shellsuggested
# Shellgitlab
# Shellregion
# Shellaware
# Shellrsyslog
# Shellios
# Shelldonation
# Shelldiff
# Shell35
# Shellprompts
# Shellh3
# Shelltried
# Shellplasma
# Shellalgorithms
# Shelldisks
# Shellsomeone
# Shelluri
# Shellcomparison
# Shellsql
# Shellsharing
# Shellcouple
# Shellexpression
# Shellsi
# Shelloverrides
# Shellmerged
# Shelltrust
# Shellsyu
# Shelluniversal
# Shellshift
# Shellembedded
# Shellair
# Shellutc
# Shelldocumented
# Shellunpack
# Shell2016
# Shellrsync
# Shellpick
# Shellmodifying
# Shellwheezy
# Shellplaylist
# Shelldevelop
# Shelllimitations
# Shellnbsp
# Shellreceive
# Shellsomewhere
# Shellcursor
# Shellsites
# Shellquiet
# Shellreceived
# Shellasking
# Shellselinux
# Shellexpress
# Shellfs
# Shellvar
# Shelllua
# Shellbackpac
# Shellintegrated
# Shellunderstanding
# Shelllogged
# Shelloverwrite
# Shellmono
# Shellkodi
# Shellautomation
# Shelllib
# Shelllocations
# Shellpor
# Shellaliases
# Shelldoc
# Shellhdmi
# Shellsublime
# Shellpacket
# Shellblank
# Shellhuman
# Shellworkspaces
# Shellnotifications
# Shellmais
# Shellscientific
# Shelldidnt
# Shelloffice
# Shellcross
# Shellbspwm
# Shellhidden
# Shellips
# Shellfavorite
# Shellunsupervised
# Shellimproved
# Shellassumes
# Shellever
# Shellconflicts
# Shellconfirm
# Shellquery
# Shell00
# Shelledge
# Shellassigned
# Shellappear
# Shelltdtr
# Shellnonroot
# Shellchecksum
# Shellnavigate
# Shelldual
# Shelljobs
# Shellyarn
# Shelldisclaimer
# Shellpowerful
# Shellcontained
# Shellimplement
# Shellill
# Shellcondition
# Shellmunge
# Shellaccepted
# Shellwarnings
# Shellzone
# Shellterraform
# Shellcon
# Shellhide
# Shellbring
# Shelllanguages
# Shellbeta
# Shellamd
# Shelltranslation
# Shellpattern
# Shellitem
# Shellattack
# Shellparent
# Shellpreinstalled
# Shellpr
# Shellcipher
# Shellrpm
# Shellbrowsers
# Shellarchiso
# Shellreduce
# Shelletclocaltimeetclocaltimero
# Shelltips
# Shelloraclelinux
# Shelloriginally
# Shellcarefully
# Shellsubnet
# Shellmostly
# Shellworker
# Shellrename
# Shellarticle
# Shellasked
# Shellsleep
# Shellfunctional
# Shellrestricted
# Shelltray
# Shellwidth
# Shellclassification
# Shellrerun
# Shellpip3
# Shellsearching
# Shelldigital
# Shelldistribute
# Shellboards
# Shellvi
# Shellfamily
# Shelldebhelper
# Shellrecipe
# Shellsuffix
# Shellterm
# Shellmatrix
# Shellwarranties
# Shellremaining
# Shellfi
# Shellfields
# Shelldeclarations
# Shellkeyring
# Shellimproving
# Shelldocuments
# Shelltimer
# Shelletcsshsshd_config
# Shellsmaller
# Shelltoolkit
# Shellsuggest
# Shellhand
# Shellfish
# Shellbehaviour
# Shellperl
# Shellattached
# Shellbenchmarks
# Shellcommits
# Shellinvoke
# Shellprocessor
# Shellfar
# Shelldevsda1
# Shellproviders
# Shellconfigurar
# Shelldefining
# Shellanyway
# Shellcapture
# Shellcountry
# Shell1000
# Shellparsing
# Shell2015
# Shellsamba
# Shellmongodb
# Shellyubikey
# Shellxml
# Shellmagic
# Shellun
# Shellinitialize
# Shellcompliance
# Shellhomebrew
# Shellproceed
# Shellaway
# Shellrespectively
# Shellreinstall
# Shellenhanced
# Shellopened
# Shelldie
# Shelltelegraf
# Shellnewest
# Shellzshrc
# Shelllos
# Shellsetenv
# Shellbasis
# Shellreturns
# Shelllife
# Shellspecifically
# Shellstdeb
# Shellunlike
# Shelllarger
# Shellusrlocalbin
# Shellword
# Shellide
# Shellmoving
# Shellparallel
# Shellonto
# Shellusual
# Shellaarch64
# Shellperson
# Shell23
# Shelldevsda
# Shellprovisioning
# Shelldragonfire
# Shellx11
# Shellsetupsh
# Shell2020
# Shellalignleft
# Shellmounts
# Shellautoremove
# Shellrecursive
# Shelladduser
# Shellrequirement
# Shellaufs
# Shelllogic
# Shellii
# Shellpointer
# Shellclipboard
# Shellreporting
# Shellredistribute
# Shelldpkgbuildpackage
# Shell2204
# Shellcmd
# Shellnb
# Shellcleanup
# Shellazure
# Shellmesa
# Shellformatted
# Shellstdout
# Shellex
# Shelldpkgreconfigure
# Shelllaunched
# Shellchinese
# Shellroute
# Shellfocused
# Shellnonfree
# Shelleasiest
# Shelldockerhub
# Shellcompositor
# Shellminor
# Shellunknown
# Shelldataset
# Shellframe
# Shellemmc
# Shellgdm
# Shelltracking
# Shellunmount
# Shellremoval
# Shellshowing
# Shelltelegram
# Shellping
# Shellworked
# Shellsysctl
# Shelloffline
# Shell700
# Shelldel
# Shelluptodate
# Shellmedium
# Shellcovered
# Shelldeny
# Shellworkaround
# Shellcharge
# Shelldeal
# Shelletchosts
# Shellfinish
# Shelltensorflow
# Shellforwarding
# Shelludev
# Shellnos
# Shellchosen
# Shelladapter
# Shellfailure
# Shellprecise
# Shellneofetch
# Shellrespective
# Shellgrab
# Shellsudoers
# Shelltrove
# Shellsolaris
# Shellchain
# Shellconvolutional
# Shellpop
# Shellgib
# Shellfdisk
# Shellcalling
# Shellisc
# Shellmaterial
# Shellexpose
# Shelleveryone
# Shellmanifest
# Shellreported
# Shelllayouts
# Shellspaces
# Shellti
# Shelldeleted
# Shellproperty
# Shellcontribution
# Shellarchives
# Shelllimits
# Shellinterested
# Shellvariants
# Shellactivity
# Shellsolutions
# Shellinitialized
# Shellliability
# Shellmembers
# Shellnat
# Shelladministrator
# Shellfacebook
# Shelldifference
# Shellparty
# Shellrunit
# Shellfollowed
# Shellstrongly
# Shellexecutables
# Shelloffer
# Shellstrings
# Shellchat
# Shellappears
# Shellcustomizations
# Shellinherited
# Shellstock
# Shellbroker
# Shellliupdated
# Shellattempts
# Shelluseradd
# Shellaka
# Shelletcpacmandmirrorlist
# Shellvv
# Shelltrouble
# Shellauditing
# Shell31
# Shellast
# Shellder
# Shellseen
# Shellraid
# Shell28
# Shelldomains
# Shellcapabilities
# Shellresponse
# Shelltip
# Shellwallpapers
# Shellsector
# Shellslave
# Shellgeneralization
# Shellcgroup
# Shellapache2
# Shellconky
# Shellemulator
# Shellproc
# Shellunable
# Shellbsd
# Shellrelay
# Shellbigger
# Shellopenmp
# Shelletcaptsourceslist
# Shellisolated
# Shellrobustness
# Shellemacs
# Shelldeployed
# Shelladapt
# Shellaccordingly
# Shellsquid
# Shelldouble
# Shellobtain
# Shellspecifying
# Shellcanonical
# Shellvendor
# Shellhosted
# Shellbunch
# Shellchip
# Shellautoconf
# Shellmask
# Shellrouting
# Shelltries
# Shell42
# Shelltex
# Shelllots
# Shellmanjaro
# Shelluid
# Shellarcolinux
# Shell33
# Shelloffers
# Shellpacmankey
# Shellseem
# Shelllatex
# Shellcrash
# Shellconvenient
# Shellproprietary
# Shellearly
# Shellconfigurable
# Shellpossibly
# Shellmkinitcpio
# Shellbzip2
# Shelltaking
# Shelladb
# Shelllicence
# Shellinsecure
# Shell2013
# Shellgimp
# Shellfstab
# Shelladaptive
# Shellnovnc
# Shellmeaning
# Shellarchlinuxcn
# Shellphpmyadmin
# Shellsshd
# Shellapplies
# Shelldelay
# Shellopencv
# Shelldunst
# Shellprints
# Shellactivated
# Shellnamespace
# Shellfiletxt
# Shellupdatercd
# Shellhelpful
# Shell20201223
# Shellguidelines
# Shelldolibarr
# Shellcredit
# Shellelectron
# Shelltoggle
# Shellbegin
# Shellfail2ban
# Shellcomma
# Shell3x
# Shellstream
# Shellhaproxy
# Shelldiscussion
# Shellth
# Shellplain
# Shellparsec
# Shellamis
# Shellrhel
# Shellinspect
# Shellbuildbot
# Shellinspired
# Shelllayers
# Shellcloudinit
# Shellvariety
# Shellunfortunately
# Shellmoved
# Shellclang
# Shellsshkeygen
# Shellfhem
# Shelldevel
# Shellsourceslist
# Shellsupervisor
# Shellnon
# Shellmark
# Shellnas
# Shellidentify
# Shellbeyond
# Shell2048
# Shellsparse
# Shellregularly
# Shellhacking
# Shellmulti
# Shellyears
# Shell2012
# Shelleffort
# Shellregistry
# Shellartifacts
# Shellcomputers
# Shellvariational
# Shellattribute
# Shellgrant
# Shell433
# Shelllength
# Shellupstart
# Shellconvenience
# Shellbare
# Shellregenerate
# Shellrebuilt
# Shellbasico
# Shellnight
# Shellattempting
# Shellpassphrase
# Shelladsysctl
# Shellcinnamon
# Shellconcept
# Shellpackaged
# Shellgpt
# Shellcomposer
# Shelllogical
# Shellv1
# Shellslightly
# Shelllo
# Shellassets
# Shellactivation
# Shellpersistent
# Shellros
# Shelljdk
# Shellclassic
# Shells3
# Shellirc
# Shelldock
# Shellmpv
# Shellz
# Shellbinsh
# Shellnautilus
# Shellsid
# Shellphpfpm
# Shellmin
# Shellequivalent
# Shellsubject
# Shelldifficult
# Shellhack
# Shellreader
# Shellxxxx
# Shelloptimize
# Shellhandles
# Shell0017caf73818
# Shellkept
# Shellmatter
# Shellplayback
# Shellphone
# Shellmodification
# Shelldeploying
# Shellguacamole
# Shellattach
# Shelleip
# Shellpossibility
# Shell56
# Shellinet
# Shellalarm
# Shelletcresolvconf
# Shellwebserver
# Shelladwatchd
# Shellmanagers
# Shellalma
# Shellesp
# Shellfloating
# Shelllan
# Shellconsistent
# Shellwide
# Shellbridge
# Shelldefault_
# Shellawk
# Shellswitching
# Shellcommented
# Shellxvf
# Shellpam
# Shellspl
# Shellmechanism
# Shellrecommendations
# Shellyml
# Shelljavascript
# Shelldistutils
# Shellsomewhat
# Shellmanner
# Shellclicking
# Shellstandalone
# Shellessential
# Shellexplanation
# Shelldebspawn
# Shellkb
# Shellhandy
# Shellovpn
# Shelldecided
# Shellcool
# Shellaif
# Shelllatent
# Shellmini
# Shellscp
# Shellauth
# Shellplug
# Shellrw
# Shell127001
# Shellrotation
# Shelloverall
# Shellcc
# Shelldmenu
# Shellwaiting
# Shellfigure
# Shellrecord
# Shell755
# Shellvarlog
# Shellcopypaste
# Shellpreconfigured
# Shellquit
# Shellfour
# Shellcontract
# Shellpaste
# Shelloverlay
# Shellmenus
# Shellrails
# Shellchef
# Shellembedding
# Shellerase
# Shellextended
# Shelldepth
# Shellestablished
# Shellamong
# Shellbtpanel
# Shellrdp
# Shelllxc
# Shell53
# Shell54
# Shellwerden
# Shelllabels
# Shellmember
# Shellpipeline
# Shellinterval
# Shellsuccess
# Shellemulation
# Shelldnsmasq
# Shellbootstrapping
# Shelldockeruser
# Shellcareful
# Shellsuit
# Shellgpus
# Shell2devnull
# Shellchecked
# Shellidentifier
# Shellcaller
# Shellmainly
# Shellsignatures
# Shellxz
# Shelldescribe
# Shellrpi
# Shellpsk
# Shellrendering
# Shellmacbook
# Shelldowngrade
# Shellpatching
# Shellreliable
# Shelldf
# Shelloutputs
# Shellwireguard_endpoint
# Shellcompletions
# Shellheight64px
# Shellsuspend
# Shellipaddress
# Shellregardless
# Shellmultilib
# Shellaffected
# Shellpackagejson
# Shellmultipass
# Shellentirely
# Shellencoding
# Shellhandled
# Shellstow
# Shellreadable
# Shellnvme
# Shelldashboard
# Shellattributes
# Shellmalware
# Shellgnupg
# Shellintegrity
# Shellsys
# Shellfullscreen
# Shellcloned
# Shellostree
# Shellflutter
# Shellcoverage
# Shellunofficial
# Shellturned
# Shellindicate
# Shellpostinst
# Shellcached
# Shellmesos
# Shellubuntus
# Shellfake
# Shellmapped
# Shellpolicies
# Shellrevision
# Shellmarked
# Shellunits
# Shellopt
# Shellissuing
# Shelldistupgrade
# Shellsynchronization
# Shellhighlight
# Shellseed
# Shellmodular
# Shellvlc
# Shellresolve
# Shellpgp
# Shellfactor
# Shellscroll
# Shellmining
# Shellspi
# Shellranger
# Shellretrieve
# Shellboots
# Shellinteresting
# Shellcombination
# Shellappreciate
# Shelltagged
# Shellcentreon
# Shellwants
# Shellpractice
# Shellarbitrary
# Shell256
# Shellaverage
# Shellinference
# Shellbspc
# Shelleffective
# Shelldefinition
# Shellleaving
# Shellpocket
# Shellextremely
# Shellexception
# Shellvscode
# Shellsolve
# Shellregex
# Shellvvv
# Shellstrong
# Shellpreset
# Shelltail
# Shellprimarily
# Shell1024
# Shellao
# Shellswarm
# Shellquickbox
# Shellsaid
# Shellcpus
# Shelltoolchain
# Shellpacstrap
# Shelltemperature
# Shellarchinstallsh
# Shellurls
# Shellhex
# Shellprotocols
# Shellvanilla
# Shelli3gaps
# Shellprecompiled
# Shelltells
# Shelluimage
# Shelldamages
# Shellstorm
# Shellcommunication
# Shellderivatives
# Shellal
# Shellpressing
# Shellplaybookyml
# Shellapplying
# Shellpre
# Shellohmyzsh
# Shellupdatealternatives
# Shellsupporting
# Shellextensive
# Shellv2ray
# Shellrolling
# Shell170
# Shellsubvolume
# Shellusable
# Shellvsftpd
# Shellproduced
# Shellprotection
# Shellfastest
# Shellstation
# Shellcoding
# Shellnaming
# Shellhelped
# Shellselecting
# Shellreadmemd
# Shell55
# Shellnotify
# Shelladdr
# Shellbatch
# Shelllaunchpad
# Shell01
# Shellcinder
# Shellphase
# Shellinteraction
# Shell4096
# Shellcursors
# Shellcaas
# Shellceilometer
# Shellbanner
# Shellalternate
# Shellbbr
# Shelluname
# Shelllead
# Shelltargz
# Shellmarkdown
# Shellproducts
# Shellcable
# Shellchoices
# Shellscale
# Shellexplain
# Shelldescriptions
# Shellprotect
# Shellrebooting
# Shellwrites
# Shellgems
# Shellsoc
# Shellfpga
# Shellfreebsd
# Shellansiblegalaxy
# Shelltranslations
# Shellscaling
# Shellobjects
# Shellcompose
# Shelldist
# Shellap
# Shellsiteyml
# Shellmean
# Shell0000
# Shellbeautiful
# Shellxps
# Shelltlp
# Shellsqueeze
# Shellunused
# Shell0600
# Shellfallback
# Shellmodes
# Shellwwwdata
# Shellaccessing
# Shellflow
# Shellopensuse
# Shellcoming
# Shellpure
# Shellflexible
# Shellparametros
# Shellsignal
# Shellinteractively
# Shelllogout
# Shelldest
# Shellaria2
# Shellunnecessary
# Shellcontainer_id
# Shelltabs
# Shellwm
# Shellgiving
# Shell44
# Shelldebsrc
# Shellact
# Shellpixel
# Shellhappy
# Shellabsolute
# Shellmodeling
# Shellgranted
# Shellsufficient
# Shelldeleting
# Shellpopulate
# Shellcolumn
# Shelldell
# Shellborder
# Shellwords
# Shellinsmod
# Shelldrwxrxrx
# Shellvariant
# Shelllibssldev
# Shellbeer
# Shellauditd
# Shellfill
# Shellwhoami
# Shellnetmask
# Shellscalable
# Shellran
# Shellbuttons
# Shellshouldnt
# Shellkeyserver
# Shelldefaultsmainyml
# Shellloadkeys
# Shellprediction
# Shellpulls
# Shellsynopsis
# Shelltlsauth
# Shelloutdated
# Shellsidedoor
# Shellwebdav
# Shellminute
# Shellhw
# Shellmali
# Shellunsupported
# Shellhomepage
# Shellself
# Shelltimestamp
# Shellwebsites
# Shellliable
# Shelldemand
# Shellarcolinuxd
# Shellmewe
# Shellfssl
# Shellskipped
# Shellmntboot
# Shelleclipse
# Shelletcsudoers
# Shellredshift
# Shellheight
# Shellreach
# Shellfairly
# Shellbuying
# Shellwsltty
# Shelltranslate
# Shellrc
# Shellasus
# Shellwlan0
# Shell1910
# Shell180
# Shelllisting
# Shellportable
# Shellzabbixserver
# Shellchar
# Shellscripting
# Shellacessar
# Shellbootgrubgrubcfg
# Shellh2
# Shellpermit
# Shellsaving
# Shellideas
# Shellpublishing
# Shell2010
# Shellinitially
# Shellnumeric
# Shellrake
# Shellprocedures
# Shellthreads
# Shellexits
# Shellgparted
# Shellxdebug
# Shelldebuild
# Shellmicrocode
# Shellworry
# Shellmonth
# Shellmenuconfig
# Shellrepeat
# Shellsemantic
# Shellhdd
# Shell800
# Shellstochastic
# Shelldevtools
# Shellrequiring
# Shellstages
# Shellplaying
# Shelltechnology
# Shellexposed
# Shellkeeping
# Shellinstallers
# Shellcover
# Shellstores
# Shellaligncenterimg
# Shellutilizando
# Shellpyenv
# Shellvarwww
# Shellfossa
# Shellnvram
# Shellstopped
# Shellpostgres
# Shelllost
# Shellperiod
# Shellforked
# Shell0000000
# Shelllogfile
# Shellyn
# Shelldevshm
# Shellag
# Shellsocial
# Shellbrbr
# Shellapplicable
# Shellbook
# Shellpotential
# Shellpowerpc
# Shellsafety
# Shelllimitation
# Shelltoday
# Shelldestroy
# Shellalpha
# Shellremovable
# Shellubuntudebian
# Shelldash
# Shellowncloud
# Shellqueries
# Shellpin
# Shellgreen
# Shellns
# Shellapple
# Shellguarantee
# Shellgid
# Shellframeworks
# Shellclosed
# Shellthread
# Shellgplv3
# Shellbuy
# Shellsensitive
# Shell51
# Shelluserland
# Shellexchange
# Shellobviously
# Shellauthorized
# Shelllibtool
# Shellomitted
# Shellpane
# Shellwidget
# Shellextend
# Shellele
# Shelllaunching
# Shelldifferences
# Shellsituation
# Shellencounter
# Shellwent
# Shellservidores
# Shellparsecmgmt
# Shellresume
# Shellrequested
# Shelldiscovery
# Shellstar
# Shellvalidate
# Shellodroid
# Shellafterwards
# Shellcaused
# Shellsymbolic
# Shellseparately
# Shellprimeiro
# Shellsymlinks
# Shellsmtp
# Shellatom
# Shellpostinstall
# Shellcodigo
# Shellbot
# Shellstig
# Shellnova
# Shellminecraft
# Shellesp8266
# Shellpythonpip
# Shellcustomizar
# Shellmod
# Shellcut
# Shelldxvk
# Shellreproducible
# Shellcompared
# Shellmisc
# Shelltalk
# Shellscsi
# Shelllsmod
# Shellrenamed
# Shellcustomizable
# Shellexact
# Shellcups
# Shellvagrantfile
# Shellhierarchical
# Shellisos
# Shellaffect
# Shell29
# Shellalacritty
# Shelldhvirtualenv
# Shellvisudo
# Shellconst
# Shellsuperuser
# Shellstay
# Shelltheyre
# Shellarising
# Shellreprepro
# Shelltransparent
# Shellexclude
# Shelllove
# Shellcecos
# Shellelements
# Shellco
# Shellideal
# Shellmd5
# Shellrecords
# Shellrepoctl
# Shellinteger
# Shellcircleci
# Shellmanages
# Shelltodos
# Shelltelnet
# Shellaurto
# Shellsays
# Shellcausing
# Shellhowto
# Shellrecording
# Shelldescribes
# Shellspec
# Shellwrote
# Shelljump
# Shellanaconda
# Shellmeet
# Shelluploaded
# Shelldados
# Shell70
# Shelltechnical
# Shellstreaming
# Shellsl
# Shellsymbols
# Shelluna
# Shellarchchroot
# Shellsane
# Shelldonations
# Shellsha256
# Shellplank
# Shelldefinitions
# Shellgoals
# Shellfrequently
# Shelldynamically
# Shellrecognition
# Shellheat
# Shellmonitors
# Shelldigitalocean
# Shellathena
# Shelltraditional
# Shellactively
# Shellcommonly
# Shellbreaking
# Shellwritable
# Shellax
# Shellrestriction
# Shell41
# Shellconversion
# Shellooniprobe
# Shelltrigger
# Shellle
# Shellasks
# Shellloopback
# Shellvon
# Shellweek
# Shellcert
# Shellvisible
# Shellsmart
# Shellentering
# Shellpbuilder
# Shellarmv7
# Shellssid
# Shelldesktops
# Shellstaging
# Shellitll
# Shellchannels
# Shellbumblebee
# Shellcapable
# Shellmetrics
# Shellpeer
# Shellabsolutely
# Shellstats
# Shellbenefit
# Shellgraphic
# Shelltdbooleantd
# Shellsoft
# Shellconditional
# Shellyear
# Shellfiltering
# Shellrendered
# Shellipsec
# Shellsystemwide
# Shellcaution
# Shellcapacity
# Shelltopic
# Shellhints
# Shellexplicit
# Shellported
# Shellldap
# Shellcycle
# Shellauthorization
# Shellufwdocker
# Shellcommoncmd_bootmc
# Shellhour
# Shellpermanent
# Shellshellcheck
# Shelletcpasswd
# Shellefibootmgr
# Shelllocate
# Shellcloning
# Shellcaches
# Shellfeh
# Shellsubmodules
# Shellsizes
# Shell60
# Shellyup
# Shelltort
# Shellrestarting
# Shellkeymap
# Shellundefined
# Shelltunnel
# Shellopengl
# Shellfriendly
# Shellterminals
# Shellconsult
# Shellsafely
# Shellsdcard
# Shellobtained
# Shellparu
# Shelllogrotate
# Shellfat32
# Shellgenerator
# Shellcustomizing
# Shellfreedom
# Shellautocompletion
# Shellserve
# Shellgtk3
# Shelldecide
# Shellnov
# Shellforeign
# Shellxdotool
# Shellwebpage
# Shellloads
# Shellcompare
# Shellicmp
# Shellcombined
# Shellnegative
# Shelldropped
# Shellutf8
# Shellintend
# Shellad
# Shellled
# Shellspark
# Shellremain
# Shellrecurrent
# Shellweve
# Shellhorizontal
# Shell8x
# Shellkeeps
# Shellcoreutils
# Shellbackports
# Shellfqdn
# Shelldot
# Shellautomake
# Shelldi
# Shellshut
# Shellrecreate
# Shellhmac
# Shelldeps
# Shellinputs
# Shellexplained
# Shellswapfile
# Shellwin
# Shellcategory
# Shelldbus
# Shelluc
# Shellaptitude
# Shell26
# Shelllsblk
# Shelldan
# Shellsplash
# Shellopenvmtools
# Shellrespin
# Shellbecomes
# Shellautoinstall
# Shellservicos
# Shellroutes
# Shellcontrolled
# Shellalter
# Shelladaptation
# Shell0700
# Shellmkl
# Shellpair
# Shellapk
# Shellmycroft
# Shellriscv
# Shelllaptops
# Shellcritical
# Shellsimilarly
# Shellindicates
# Shellblacklist
# Shelllibs
# Shelljs
# Shellscenarios
# Shelldebos
# Shellimagemagick
# Shell120
# Shellfrequency
# Shellsubmitting
# Shelladvantage
# Shellblue
# Shellstatistics
# Shellobtaining
# Shellversao
# Shelleventually
# Shellsdist_dsc
# Shellthunar
# Shell3306
# Shellxe
# Shellarchey
# Shellallinone
# Shellstandards
# Shellcertified
# Shellaberto
# Shellwizard
# Shellelementary
# Shellholds
# Shellclaim
# Shelldirection
# Shellv3
# Shellprawnos
# Shelltim
# Shellrecently
# Shelluserspace
# Shellmaas
# Shellregularization
# Shellpractices
# Shellchina
# Shellpointing
# Shellteamcity
# Shellbandwidth
# Shell2021
# Shellshells
# Shellbuildarg
# Shellscreens
# Shellvulnerable
# Shellmtu
# Shellquickstart
# Shellperforms
# Shellimpact
# Shellcaching
# Shellinc
# Shellinvoked
# Shellkafka
# Shellposix
# Shellbreaks
# Shellappearance
# Shellasterisk
# Shellpurging
# Shellpci
# Shellparam
# Shelldes
# Shellguess
# Shellextraction
# Shellunicode
# Shellpatched
# Shellautomates
# Shellibm
# Shellbindings
# Shellpast
# Shellhybrid
# Shellvobcopy
# Shellmaven
# Shellnightly
# Shellwar
# Shell7zip
# Shellpicom
# Shellparse
# Shellcodename
# Shellprs
# Shellexecutes
# Shellmmc
# Shellpersonally
# Shellsemisupervised
# Shellworkers
# Shellcompton
# Shelljohn
# Shellderived
# Shellstates
# Shellvalue_
# Shelllistening
# Shell386
# Shellcolour
# Shellworth
# Shelloses
# Shelllite
# Shellgraphs
# Shellnoinstallrecommends
# Shellreserved
# Shellnoexec
# Shelldescribing
# Shellcryptsetup
# Shellallall
# Shelldesignate
# Shelltarballs
# Shellexpand
# Shellassistant
# Shell115
# Shellarrow
# Shelllibvirt
# Shell_default
# Shellms
# Shellflashing
# Shellreflector
# Shellpreserve
# Shellwallet
# Shellindependent
# Shellrootdemondev
# Shellaide
# Shellbro
# Shelleeprom
# Shellownership
# Shellmkfsext4
# Shellencourage
# Shell267
# Shellwhose
# Shellsynchronize
# Shell633
# Shelldeepinwine
# Shelli2cmshw003000
# Shellelectroninstallerdebian
# Shelldeno
# Shelltimedatectl
# Shellvimrc
# Shellguided
# Shellrescue
# Shellbaseos
# Shellpack
# Shellvartmp
# Shellidentity
# Shellinterest
# Shellreplacement
# Shelldevsdc
# Shelladeb
# Shellinvocation
# Shellfilters
# Shelladministration
# Shellparte01
# Shellqemukvm
# Shellpredefined
# Shellinstruction
# Shellsolid
# Shellwireguard_address
# Shell90
# Shellraspap
# Shelli2c_hid
# Shellanywhere
# Shellreadwrite
# Shellpathname
# Shellefficiency
# Shellopens
# Shelltbody
# Shellcreative
# Shellconnectivity
# Shellecdsa
# Shellmib
# Shellmaintaining
# Shellminimize
# Shell4gb
# Shellhuge
# Shellglance
# Shellbase00
# Shellqemuuserstatic
# Shelllaunches
# Shellbelieve
# Shellvertical
# Shellparallels
# Shellreplacing
# Shell443
# Shelldeployments
# Shellbundled
# Shellfazer
# Shellmodules_install
# Shellfoi
# Shellpipewire
# Shelletcdefaultgrub
# Shellcreator
# Shellminer
# Shellscanning
# Shellassign
# Shell10000
# Shellmime
# Shellprotected
# Shelllack
# Shellpgid0
# Shellrecommends
# Shellaffects
# Shell2222
# Shellunified
# Shellcrypto
# Shellremotely
# Shellscheduler
# Shellships
# Shellplaces
# Shellusrbin
# Shellein
# Shellslower
# Shelltouchscreen
# Shellaskbecomepass
# Shellstars
# Shellarchaudit
# Shellbrowsing
# Shellgtx
# Shellsupplied
# Shellsubdirectories
# Shelllsb_release
# Shellsignificant
# Shelllocalmodconfig
# Shellvulnerabilities
# Shellelsewhere
# Shellsimplest
# Shellmoves
# Shellpayload
# Shellsourced
# Shelltooling
# Shelladditions
# Shellumask000
# Shellchild
# Shelldevscripts
# Shellguidance
# Shellarchamd64
# Shellacls
# Shelltypical
# Shelletcrclocal
# Shellsentry
# Shellha
# Shellsupply
# Shellcomando
# Shellembeddings
# Shelltransport
# Shellactivities
# Shellcrossplatform
# Shellpaper
# Shellignoring
# Shellelixir
# Shellhence
# Shellwipe
# Shellowned
# Shellmaldet
# Shellprivoxy
# Shellequal
# Shellauthenticate
# Shellnatural
# Shellprevents
# Shell43
# Shellnan
# Shellterceiro
# Shellstereo
# Shellwrappers
# Shellnetdata
# Shell150
# Shellachieve
# Shellpuid0
# Shelldaemonreload
# Shellac
# Shellcalamares
# Shellnear
# Shell2gb
# Shellcentral
# Shell2000
# Shellglibc
# Shelluart
# Shelltheory
# Shellslim
# Shellbody
# Shellswitches
# Shellintroduced
# Shellmodprobe
# Shellhereby
# Shellpain
# Shelldeveloping
# Shellgpio
# Shellnetctl
# Shellmanpages
# Shelleth1
# Shelltdimg
# Shellsecureboot
# Shellredirects
# Shellzu
# Shellreuse
# Shellcoffee
# Shellreddit
# Shellentrypoint
# Shelloperate
# Shell110
# Shellfire
# Shellnodedeb
# Shellflavor
# Shellsessions
# Shelltechnologies
# Shell37
# Shellhadoop
# Shellhashes
# Shellxterm
# Shellsbinmy_init
# Shellneutron
# Shellverified
# Shellpostinstallation
# Shelljammy
# Shellbusybox
# Shellcauses
# Shellfakemachine
# Shellintegrate
# Shellexpects
# Shellincorrect
# Shelltldr
# Shellunprivileged
# Shellexploration
# Shellinstallationinstallation
# Shellpuid
# Shellsetuptermuxarch
# Shellsell
# Shelldebtap
# Shellscheduling
# Shellmultimedia
# Shellrequirementstxt
# Shelltransactions
# Shellrefers
# Shellextras
# Shellbadge
# Shell36
# Shelldjango
# Shellsampling
# Shellsrcinfo
# Shellfavourite
# Shellacl
# Shellfat
# Shellsubsequent
# Shellraise
# Shellpreparing
# Shellvector
# Shellxdg
# Shellrender
# Shellbootstrapvz
# Shellimprovement
# Shellaccurate
# Shellbrowse
# Shellmarvell
# Shellredirect
# Shellhp
# Shellpgid
# Shellstructures
# Shellsubmitted
# Shellestimation
# Shellsetups
# Shelleste
# Shelldevsda2
# Shellids
# Shellperforming
# Shellantes
# Shellaqi
# Shellyaru
# Shelldetach
# Shell38
# Shellsilent
# Shelledp1
# Shellsurface
# Shellsobre
# Shellesp32
# Shellmappings
# Shellboost
# Shelltraefik
# Shelllatency
# Shellgalaxy
# Shellp1
# Shellxfs
# Shellportions
# Shellsolving
# Shellcategories
# Shellsimulate
# Shellpkgconfig
# Shellunpacking
# Shellease
# Shellreinstalling
# Shelldrag
# Shelllxqt
# Shelleffects
# Shellstartx
# Shellvoid
# Shellxorriso
# Shellpicture
# Shellnftables
# Shellp7zip
# Shellflat
# Shellpatterns
# Shellfinding
# Shellanswers
# Shellfusion
# Shellmicrosd
# Shellmetric
# Shelliface
# Shellsubsystem
# Shellwildcard
# Shellweight
# Shell450
# Shellchroots
# Shellb3
# Shell116
# Shellnvm
# Shelldialogue
# Shellpulling
# Shellpythondev
# Shelllegal
# Shellfastboot
# Shelldh
# Shellrecompile
# Shelldockerfiles
# Shellhot
# Shellatualizar
# Shelltrash
# Shellcontrollers
# Shellsegundo
# Shellinterpreter
# Shellpacback
# Shellwhite
# Shellalongside
# Shellrev
# Shellpreference
# Shellrubygems
# Shellrequirementsyml
# Shellciphers
# Shellformatting
# Shelletcgroup
# Shellcertbot
# Shellpartial
# Shell_vps_
# Shellrelatively
# Shellelapsed
# Shellcss
# Shelletcd
# Shellasf
# Shellseu
# Shellwpa_supplicant
# Shellrollback
# Shellextracting
# Shellwheels
# Shellgreatly
# Shellwww
# Shellautomations
# Shellcommunicate
# Shelllemp
# Shellvhost
# Shellplugged
# Shellescape
# Shelltomcat9
# Shelladjusting
# Shellpode
# Shellcargo
# Shellscrolling
# Shell2nd
# Shellpreparation
# Shellrust
# Shellreduces
# Shellxubuntu
# Shellninja
# Shelladvised
# Shellreleaseh3
# Shellabort
# Shelloneinstack
# Shellchose
# Shellinstala
# Shellperhaps
# Shellprofessional
# Shell3b
# Shellmaps
# Shelljournal
# Shellmacosmojave
# Shellopenvpninstallsh
# Shellmips
# Shellblocked
# Shellholders
# Shellstrict
# Shellhyperv
# Shelldevsda3
# Shelltile
# Shellfn
# Shellpopup
# Shellforever
# Shelldropbox
# Shell46
# Shelltlscrypt
# Shellaccessed
# Shellthirdparty
# Shellconflict
# Shellrelies
# Shellnatively
# Shellartifactory
# Shelldisc
# Shelllinking
# Shellrecipes
# Shelljvm
# Shelldetailssummary
# Shellunset
# Shellnodev
# Shelltables
# Shellprivilege
# Shellbootm
# Shellcac
# Shellohomenamebuildkernel
# Shelllivebuild
# Shellrecvkeys
# Shell3rd
# Shellweather
# Shellprinted
# Shellpacaur
# Shellgerenciamento
# Shellship
# Shellheavily
# Shellrestarts
# Shelladvantages
# Shellessentially
# Shelleffectively
# Shellratio
# Shellemails
# Shelldc
# Shellascii
# Shellunencrypted
# Shellen_usutf8
# Shell5000
# Shellsamples
# Shellbleachbit
# Shelllatter
# Shell117
# Shellextractor
# Shellcleaner
# Shellsectors
# Shellautoencoders
# Shellkindle
# Shelloder
# Shellcompletes
# Shelldumps
# Shellgolang
# Shelllearned
# Shellroothost
# Shellobs
# Shellargon
# Shelldetermines
# Shellhibernation
# Shelltermxterm
# Shellidle
# Shelltdtttruetttd
# Shellmultiagent
# Shellticket
# Shelldput
# Shellexpansion
# Shellstops
# Shell57
# Shellumask
# Shellguests
# Shelllose
# Shellxzf
# Shellnerd
# Shellago
# Shellplanning
# Shelletchostname
# Shelldecoding
# Shellpotentially
# Shellpng
# Shellpairs
# Shellgeforce
# Shelli686
# Shellpem
# Shellsistemas
# Shellstartsh
# Shellkeystone
# Shellsnippet
# Shellbusiness
# Shellwebmin
# Shellexported
# Shellcronjob
# Shellprepared
# Shellposition
# Shellcontributor
# Shelldetail
# Shell375
# Shellqutebrowser
# Shellhhvm
# Shellcomandos
# Shellcompany
# Shellnamecontainer
# Shellopenfans
# Shelltoplevel
# Shellskype
# Shellpositive
# Shellseparator
# Shellesta
# Shellstudy
# Shellsubstantial
# Shellmetalearning
# Shellexpiration
# Shellalignment
# Shellsubiquity
# Shellspeech
# Shellabsent
# Shellsubversion
# Shellwebtop
# Shellperfect
# Shellruntests
# Shellresponses
# Shellcombine
# Shelldevsdx
# Shellgovernor
# Shellconsists
# Shellapplet
# Shellart
# Shelldetects
# Shellshadowsocksr
# Shellassistance
# Shellapu
# Shelldivided
# Shellconsumption
# Shellhaskell
# Shellpxe
# Shellsqlite
# Shellreleasing
# Shellpadding
# Shelllmd
# Shelldaemons
# Shelldryrun
# Shellannoying
# Shellbroadcast
# Shellsimplify
# Shellrunadsysdsock
# Shellresolved
# Shelldockerservice
# Shellachieved
# Shellneighbor
# Shellwired
# Shelloverriding
# Shellwarned
# Shellstatically
# Shellconfirmation
# Shellcontinual
# Shell0755
# Shellarmbian
# Shellheld
# Shellarc
# Shellbayesian
# Shellarchived
# Shellharden
# Shellocean
# Shellerr
# Shellals
# Shellarchbox
# Shellunlock
# Shell81
# Shellcommons
# Shelletcsystemdsystem
# Shellcommercial
# Shellpreferably
# Shellhaxe
# Shellnamespaces
# Shellmine
# Shellinvolved
# ...
# Otherslinear
# Othersbdist_deb
# Otherslint
# Othersreboots
# Othersaptmetalink
# Othersfeed
# Othersaimg
# Othersreads
# Othersbootstrapsh
# Othersbootargs
# Othersgnuroot
# Othersinactive
# Othersfactors
# Otherscvescan
# Othersthunderbird
# Othersmotd
# Othersexpanded
# Othersbookmarks
# Otherssvn
# Otherscollect
# Otherspasswordless
# Otherssystemdboot
# Otherscircumstances
# Othersperspective
# Othersstands
# Othersyellow
# Othersfuzzy
# Othersalone
# Othersraspberrypi
# Othersunselected
# Othersdead
# Othersmod_key
# Othersuserroot
# Othersviewed
# Othersrtc
# Othersslurmd
# Othersphalcon
# Otherslxdm
# Othersplanned
# Otherskeyword
# Othersshipped
# Othersalle
# Otherssends
# Otherslinuxfirmware
# Otherscompanies
# Othersconsist
# Otherscustomizer
# Others115200
# Otherslemper
# Otherspulled
# Othersnormalization
# Othersthinking
# Othersrestarted
# Othersnumerous
# Othersrare
# Othersiphone
# Others128

# %%
percentages = pd.DataFrame({"top_5000_words": top_1000.index, 'shell': shell_percentages, 'python': python_percentages, 'c': c_percentages, 'other_langs': other_lang_percentages})

# %%
percentages.head()
# Out:
#   top_5000_words   shell  python       c  other_langs
# 0        install  0.5982  0.6159  0.5957       0.5457
# 1            use  0.5375  0.5952  0.5887       0.5547
# 2            run  0.5438  0.5606  0.5177       0.5367
# 3           file  0.3961  0.5190  0.5248       0.4698
# 4         script  0.4781  0.2215  0.2766       0.2188

# %%
percentages['range'] = None
for row in range(len(percentages)):
    max = 0
    min = 1
    for column in percentages.drop(columns = ['top_5000_words', 'range']).columns:
        if percentages[column][row] > max:
            max = percentages[column][row]
        if percentages[column][row] < min:
            min = percentages[column][row]
    percentages['range'][row] = (max - min)
# Out:
# /var/folders/r6/g880v64s6vj401drwcc37nf00000gn/T/ipykernel_21452/3575129718.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   percentages['range'][row] = (max - min)

# %%
percentages[['top_5000_words', 'range']][percentages.range < .01].top_5000_words.to_json('high_freq_stopwords.json')

# %%
percentages[['top_5000_words', 'range']][percentages.range < .01].top_5000_words
# Out:
# 149          tdtd
# 159             v
# 161      learning
# 181        intelr
# 354          para
#           ...
# 4994     thinking
# 4995    restarted
# 4996     numerous
# 4997         rare
# 4999          128
# Name: top_5000_words, Length: 1644, dtype: object

# %%
percentages[['top_5000_words', 'range']].sort_values(by = 'range', ascending = False).head(179)
# Out:
#      top_5000_words   range
# 105          python  0.4554
# 11           kernel  0.2729
# 4            script  0.2593
# 391         compile  0.2347
# 780             gcc  0.2315
# ...             ...     ...
# 705            less  0.1002
# 847           never  0.1001
# 813          reason  0.1001
# 20            files  0.1001
# 1284          fails     0.1
#
# [179 rows x 2 columns]

# %%
percentages
# Out:
#      top_5000_words   shell  python       c  other_langs   range
# 0           install  0.5982  0.6159  0.5957       0.5457  0.0702
# 1               use  0.5375  0.5952  0.5887       0.5547  0.0577
# 2               run  0.5438  0.5606  0.5177       0.5367  0.0429
# 3              file  0.3961  0.5190  0.5248       0.4698  0.1287
# 4            script  0.4781  0.2215  0.2766       0.2188  0.2593
# ...             ...     ...     ...     ...          ...     ...
# 4995      restarted  0.0056  0.0069  0.0071       0.0051   0.002
# 4996       numerous  0.0056  0.0104  0.0071       0.0039  0.0065
# 4997           rare  0.0075  0.0035  0.0071       0.0039   0.004
# 4998         iphone  0.0019  0.0000  0.0142       0.0039  0.0142
# 4999            128  0.0081  0.0035  0.0071       0.0013  0.0068
#
# [5000 rows x 6 columns]
