# %%
#import tools for web scraping:
from requests import get
from bs4 import BeautifulSoup
import os
import pandas as pd

#group imports
import env
import acquire
import constants_prepare

import json
from typing import Dict, List, Optional, Union, cast
import requests

#visualizations:
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ADDITIONAL_STOPWORDS = [
    'sudo',
    'distro',
    'linux',
    'aptget',
    'ubuntu',
    'debian',
    'arch',
    'archlinux',
    'git',
    'root',
    'img',
    'instal',
    'use',
    'user',
    'packag',
    'file',
    'run',
    'system',
    'configur',
    'script',
    'set',
    'build',
    'need',
    'make',
    'option',
    'creat',
    'default'
]
def get_stopwords_from_file():
    """This function takes in the 5,000 top words that have a 1%
    difference or less of similarity between programming languages
    And adds these words onto the stopwords list"""
    with open('high_freq_stopwords.json', 'r') as f:
        add_stop_words_list = json.load(f) 
    return list(add_stop_words_list.values())+ ADDITIONAL_STOPWORDS

# %%
 stopwords = nltk.corpus.stopwords.words('english') + get_stopwords_from_file()

# %% [markdown]
# _____________________________________________________________________________

# %% [markdown]
# ## Exploring Ubuntu:

# %%
ubuntu = pd.read_json('ubuntu_data.json')

# %%
ubuntu.head()
# Out:
#                              repo language  \
# 0               dockerfile/ubuntu    Shell
# 1                boxcutter/ubuntu    Shell
# 2     wszqkzqk/deepin-wine-ubuntu        C
# 3  fcwu/docker-ubuntu-vnc-desktop     HTML
# 4             docker-32bit/ubuntu    Shell
#
#                                      readme_contents
# 0  ## Ubuntu Dockerfile\n\n\nThis repository cont...
# 1  # Packer templates for Ubuntu written in legac...
# 2  # Deepin wine for Ubuntu and Debian\n\n## 一、项目...
# 3  # docker-ubuntu-vnc-desktop\n\n[![Docker Pulls...
# 4  ubuntu\n======\n\nBuild a docker image for ubu...

# %% [markdown]
# #### Normalizing the data:

# %%
import unicodedata
import re

import nltk
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords

# %%
#to view just one of the readme docs and see what kind of normalizing is needed:
soup = BeautifulSoup(ubuntu.readme_contents.iloc[10], 'html.parser')
soup
# Out:
# Ubuntu 18.04 CIS STIG
# ================
#
# [![Build Status](https://travis-ci.com/florianutz/Ubuntu1804-CIS.svg?branch=master)](https://travis-ci.com/florianutz/Ubuntu1804-CIS)
# [![Ansible Role](https://img.shields.io/badge/role-florianutz.Ubuntu1804--CIS-blue.svg)](https://galaxy.ansible.com/florianutz/Ubuntu1804-CIS/)
#
# Configure Ubuntu 18.04 machine to be CIS compliant. Level 1 and 2 findings will be corrected by default.
#
# This role **will make changes to the system** that could break things. This is not an auditing tool but rather a remediation tool to be used after an audit has been conducted.
#
# ## IMPORTANT INSTALL STEP
#
# If you want to install this via the `ansible-galaxy` command you'll need to run it like this:
#
# `ansible-galaxy install -p roles -r requirements.yml`
#
# With this in the file requirements.yml:
#
# ```
# - src: https://github.com/florianutz/Ubuntu1804-CIS.git
# ```
#
# Based on [CIS Ubuntu Benchmark v2.0.1 - 01-03-2020 ](https://www.cisecurity.org/cis-benchmarks/).
#
# This repo originated from work done by [MindPointGroup](https://github.com/MindPointGroup/RHEL7-CIS)
#
# Requirements
# ------------
#
# You should carefully read through the tasks to make sure these changes will not break your systems before running this playbook.
#
# Role Variables
# --------------
# There are many role variables defined in defaults/main.yml. This list shows the most important.
#
# **ubuntu1804cis_notauto**: Run CIS checks that we typically do NOT want to automate due to the high probability of breaking the system (Default: false)
#
# **ubuntu1804cis_section1**: CIS - General Settings (Section 1) (Default: true)
#
# **ubuntu1804cis_section2**: CIS - Services settings (Section 2) (Default: true)
#
# **ubuntu1804cis_section3**: CIS - Network settings (Section 3) (Default: true)
#
# **ubuntu1804cis_section4**: CIS - Logging and Auditing settings (Section 4) (Default: true)
#
# **ubuntu1804cis_section5**: CIS - Access, Authentication and Authorization settings (Section 5) (Default: true)
#
# **ubuntu1804cis_section6**: CIS - System Maintenance settings (Section 6) (Default: true)
#
# ##### Disable all selinux functions
# `ubuntu1804cis_selinux_disable: false`
#
# ##### Service variables:
# ###### These control whether a server should or should not be allowed to continue to run these services
#
# ```
# ubuntu1804cis_avahi_server: false
# ubuntu1804cis_cups_server: false
# ubuntu1804cis_dhcp_server: false
# ubuntu1804cis_ldap_server: false
# ubuntu1804cis_telnet_server: false
# ubuntu1804cis_nfs_server: false
# ubuntu1804cis_rpc_server: false
# ubuntu1804cis_ntalk_server: false
# ubuntu1804cis_rsyncd_server: false
# ubuntu1804cis_tftp_server: false
# ubuntu1804cis_rsh_server: false
# ubuntu1804cis_nis_server: false
# ubuntu1804cis_snmp_server: false
# ubuntu1804cis_squid_server: false
# ubuntu1804cis_smb_server: false
# ubuntu1804cis_dovecot_server: false
# ubuntu1804cis_httpd_server: false
# ubuntu1804cis_vsftpd_server: false
# ubuntu1804cis_named_server: false
# ubuntu1804cis_bind: false
# ubuntu1804cis_vsftpd: false
# ubuntu1804cis_httpd: false
# ubuntu1804cis_dovecot: false
# ubuntu1804cis_samba: false
# ubuntu1804cis_squid: false
# ubuntu1804cis_net_snmp: false
# ```
#
# ##### Designate server as a Mail server
# `ubuntu1804cis_is_mail_server: false`
#
#
# ##### System network parameters (host only OR host and router)
# `ubuntu1804cis_is_router: false`
#
#
# ##### IPv6 required
# `ubuntu1804cis_ipv6_required: true`
#
#
# ##### AIDE
# `ubuntu1804cis_config_aide: true`
#
# ###### AIDE cron settings
# ```
# ubuntu1804cis_aide_cron:
#   cron_user: root
#   cron_file: /etc/crontab
#   aide_job: '/usr/sbin/aide --check'
#   aide_minute: 0
#   aide_hour: 5
#   aide_day: '*'
#   aide_month: '*'
#   aide_weekday: '*'
# ```
#
#
# ##### Set to 'true' if X Windows is needed in your environment
# `ubuntu1804cis_xwindows_required: no`
#
#
# ##### Client application requirements
# ```
# ubuntu1804cis_openldap_clients_required: false
# ubuntu1804cis_telnet_required: false
# ubuntu1804cis_talk_required: false
# ubuntu1804cis_rsh_required: false
# ubuntu1804cis_ypbind_required: false
# ```
#
# ##### Time Synchronization
# ```
# ubuntu1804cis_time_synchronization: chrony
# ubuntu1804cis_time_Synchronization: ntp
#
# ubuntu1804cis_time_synchronization_servers:
#   - uri: "0.pool.ntp.org"
#     config: "minpoll 8"
#   - uri: "1.pool.ntp.org"
#     config: "minpoll 8"
#   - uri: "2.pool.ntp.org"
#     config: "minpoll 8"
#   - uri: "3.pool.ntp.org"
#     config: "minpoll 8"
#
# ```
# ##### - name: "SCORED | 1.1.5 | PATCH | Ensure noexec option set on /tmp partition"
# It is not implemented, noexec for /tmp will disrupt apt. /tmp contains executable scripts during package installation
# ```
#
# ```
# ##### 1.5.3 | PATCH | Ensure authentication required for single user mode
# It is disabled by default as it is setting random password for root. To enable it set:
# ```yaml
# ubuntu1804cis_rule_1_5_3: true
# ```
# To use other than random password:
# ```yaml
# ubuntu1804cis_root_password: 'new password'
# ```
#
# ##### 3.4.2 | PATCH | Ensure /etc/hosts.allow is configured
# ```
# ubuntu1804cis_host_allow:
#   - "10.0.0.0/255.0.0.0"
#   - "172.16.0.0/255.240.0.0"
#   - "192.168.0.0/255.255.0.0"
# ```
#
# ```
# ubuntu1804cis_firewall: firewalld
# ubuntu1804cis_firewall: iptables
# ```
#
# ##### 5.3.1 | PATCH | Ensure password creation requirements are configured
# ```
# ubuntu1804cis_pwquality:
#   - key: 'minlen'
#     value: '14'
#   - key: 'dcredit'
#     value: '-1'
#   - key: 'ucredit'
#     value: '-1'
#   - key: 'ocredit'
#     value: '-1'
#   - key: 'lcredit'
#     value: '-1'
# ```
#
#
# Dependencies
# ------------
#
# Ansible &gt;= 2.4 and &lt;= 2.7 (2.8 is not yet supported)
#
# Example Playbook
# -------------------------
#
# ```
# - name: Harden Server
#   hosts: servers
#   become: yes
#
#   roles:
#     - Ubuntu1804-CIS
# ```
#
# To run the tasks in this repository, first create this file one level above the repository
# (i.e. the playbook .yml and the directory `Ubuntu1804-CIS` should be next to each other),
# then review the file `defaults/main.yml` and disable any rule/section you do not wish to execute.
#
# Assuming you named the file `site.yml`, run it with:
# ```bash
# ansible-playbook site.yml
# ```
#
# Tags
# ----
# Many tags are available for precise control of what is and is not changed.
#
# Some examples of using tags:
#
# ```
#     # Audit and patch the site
#     ansible-playbook site.yml --tags="patch"
# ```
#
# License
# -------
#
# MIT

# %%
#getting an overall view of the data:
ubuntu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   repo             1100 non-null   object
#  1   language         964 non-null    object
#  2   readme_contents  1100 non-null   object
# dtypes: object(3)
# memory usage: 25.9+ KB

# %%
#looking at any nulls:
ubuntu.isnull().sum()
# Out:
# repo                 0
# language           136
# readme_contents      0
# dtype: int64

# %%
#dropping nulls (we found that these repos have no languages attached)
ubuntu = ubuntu.dropna()

# %%
#df w/o nulls:
ubuntu.isnull().sum()
# Out:
# repo               0
# language           0
# readme_contents    0
# dtype: int64

# %%
#seeing the unique languages:
ubuntu.language.value_counts()
# Out:
# Shell               502
# Python              105
# Dockerfile           51
# C                    44
# C++                  34
# HTML                 33
# Ruby                 27
# JavaScript           24
# Jinja                18
# Go                   12
# PHP                  12
# CSS                  11
# Makefile             11
# Puppet               10
# HCL                   9
# Jupyter Notebook      8
# Vim script            6
# Dart                  6
# PowerShell            4
# QML                   4
# Nginx                 3
# Perl                  3
# Objective-C           3
# Scheme                2
# C#                    2
# TeX                   2
# SCSS                  2
# Haskell               2
# R                     2
# M4                    1
# YAML                  1
# Rich Text Format      1
# Vue                   1
# Java                  1
# Scala                 1
# Smarty                1
# Groovy                1
# VimL                  1
# Emacs Lisp            1
# Tcl                   1
# Batchfile             1
# Name: language, dtype: int64

# %% [markdown]
# ______________________________________________

# %% [markdown]
# ## Ubuntu Languages:

# %%
#looking at the overall percentages of the top 10 languages used in Ubuntu repos:
language_counts=ubuntu.language.value_counts(normalize=True).head(10)
language_counts
# Out:
# Shell         0.520747
# Python        0.108921
# Dockerfile    0.052905
# C             0.045643
# C++           0.035270
# HTML          0.034232
# Ruby          0.028008
# JavaScript    0.024896
# Jinja         0.018672
# Go            0.012448
# Name: language, dtype: float64

# %%
#creating a df of the percentages to prep for charts:
temp = pd.DataFrame({'language' : language_counts.index, 'percentage': language_counts.values})
temp
# Out:
#      language  percentage
# 0       Shell    0.520747
# 1      Python    0.108921
# 2  Dockerfile    0.052905
# 3           C    0.045643
# 4         C++    0.035270
# 5        HTML    0.034232
# 6        Ruby    0.028008
# 7  JavaScript    0.024896
# 8       Jinja    0.018672
# 9          Go    0.012448

# %%
#plotting out the percentages of the Top 10 languages used in Ubuntu repos:
plt.figure(figsize=(10,8))
sns.barplot(data=temp, x = 'language', y = 'percentage')
# Out:
# <AxesSubplot:xlabel='language', ylabel='percentage'>

# %% [markdown]
# ## Cleaning the Data:

# %% [markdown]
# Steps to parsing data:
# - 1) Convert text to all lower case for normalcy.
# - 2) Remove any accented characters, non-ASCII characters.
# - 3) Remove special characters and html and linux related words.
# - 4) Stem or lemmatize the words.(stem = "if b, then c")
# - 5) Remove stopwords.(if, and, the, etc)
# - 6) Store the clean text and the original text for use in future notebooks.

# %%
ADDITIONAL_STOPWORDS = [
    'sudo',
    'distro',
    'linux',
    'aptget',
    'ubuntu',
    'debian',
    'arch',
    'archlinux',
    'git',
    'root',
    'image',
    'install',
    'installed',
    'installing',
    'use', 
    'user',
    'used',
    'using',
    'server',
    'kernel',
    'update',
    'package', 
    'file',
    'run', 
    'system', 
    'configure',
    'configured',
    'command',
    'script', 
    'set', 
    'build',
    'need',
    'make',
    'option',
    'contain',
    'contained',
    1,
    'server',
    'update',
    'updated',
    'kerneled',
    'version',
    '1',
    'download',
    'create', 
    'default'
    
] 

def clean_data(text):
    ps = nltk.porter.PorterStemmer()
    stopwords = nltk.corpus.stopwords.words('english') + ADDITIONAL_STOPWORDS
    text = (unicodedata.normalize('NFKD', text)
             .encode('ascii', 'ignore')
             .decode('utf-8', 'ignore')
             .lower())
    words = re.sub(r'[\(<\"]?http.*[\)>\"\s]', ' ', text).split()
    words = [re.sub(r'[^\w\s]', '', text) for text in words]
    try:
        while True:
            words.remove('')
    except ValueError:
        pass
    
    return ' '.join([ps.stem(word) for word in words if word not in stopwords])

# %%
#grabbing text from df:
ubuntu_corpus = ' '.join(ubuntu['readme_contents'])
ubuntu_corpus[:100]
# Out:
# '## Ubuntu Dockerfile\n\n\nThis repository contains **Dockerfile** of [Ubuntu](http://www.ubuntu.com/) f'

# %%
#creating a list 
ubuntu_corpus_list = clean_data(ubuntu_corpus).split()
ubuntu_corpus_list
# Out:
# ['dockerfil',
#  'repositori',
#  'contain',
#  'dockerfil',
#  'base',
#  'docker',
#  'ubuntu1404',
#  'instal',
#  'docker',
#  '2',
#  'autom',
#  'altern',
#  'dockerfil',
#  'docker',
#  'tdockerfileubuntu',
#  'githubcomdockerfileubuntu',
#  'usag',
#  'docker',
#  'rm',
#  'dockerfileubuntu',
#  'packer',
#  'templat',
#  'written',
#  'legaci',
#  'json',
#  'overview',
#  'repositori',
#  'contain',
#  'packer',
#  'current',
#  'box',
#  'longer',
#  'provid',
#  'prebuilt',
#  'binari',
#  'templat',
#  'build',
#  'vagrant',
#  'box',
#  'packer',
#  'box',
#  'virtualbox',
#  'vmware',
#  'fusion',
#  'parallel',
#  'parallel',
#  'requir',
#  'parallel',
#  'virtual',
#  'sdk',
#  'mac',
#  'addit',
#  'prerequisit',
#  'json',
#  'file',
#  'contain',
#  'variabl',
#  'specif',
#  'version',
#  'tell',
#  'packer',
#  'specif',
#  'variabl',
#  'via',
#  'varfil',
#  'line',
#  'overrid',
#  'option',
#  'core',
#  'ubuntujson',
#  'packer',
#  'templat',
#  'build',
#  '2004',
#  'exampl',
#  '2004',
#  'follow',
#  'packer',
#  'varfileubuntu2004json',
#  'ubuntujson',
#  'want',
#  'box',
#  'specif',
#  'desktop',
#  'virtual',
#  'platform',
#  'paramet',
#  'exampl',
#  '2004',
#  'virtualbox',
#  'packer',
#  'onlyvirtualboxiso',
#  'varfileubuntu2004json',
#  'ubuntujson',
#  'boxcutt',
#  'templat',
#  'current',
#  'support',
#  'follow',
#  'desktop',
#  'virtual',
#  'string',
#  'parallelsiso',
#  'parallel',
#  'virtualboxiso',
#  'virtualbox',
#  'vmwareiso',
#  'vmware',
#  'fusion',
#  'build',
#  'vagrant',
#  'box',
#  'box',
#  'weve',
#  'also',
#  'provid',
#  'wrapper',
#  'binbox',
#  'eas',
#  'altern',
#  'follow',
#  '2004',
#  'provid',
#  'binbox',
#  'ubuntu2004',
#  'want',
#  '2004',
#  'virtualbox',
#  'binbox',
#  'ubuntu2004',
#  'virtualbox',
#  'build',
#  'vagrant',
#  'box',
#  'makefil',
#  'gnu',
#  'makefil',
#  'drive',
#  'complet',
#  'basebox',
#  'creation',
#  'pipelin',
#  'follow',
#  'stage',
#  'basebox',
#  'box',
#  'file',
#  'assur',
#  'verifi',
#  'basebox',
#  'box',
#  'file',
#  'produc',
#  'function',
#  'correctli',
#  'deliv',
#  'upload',
#  'box',
#  'file',
#  'artifactori',
#  'pipelin',
#  'driven',
#  'via',
#  'follow',
#  'target',
#  'make',
#  'easi',
#  'includ',
#  'favourit',
#  'ci',
#  'tool',
#  'avail',
#  'box',
#  'type',
#  'assur',
#  'test',
#  'box',
#  'deliv',
#  'upload',
#  'box',
#  'artifact',
#  'repositori',
#  'clean',
#  'clean',
#  'detritu',
#  'proxi',
#  'set',
#  'templat',
#  'respect',
#  'follow',
#  'network',
#  'proxi',
#  'environ',
#  'variabl',
#  'forward',
#  'virtual',
#  'machin',
#  'environ',
#  'box',
#  'creation',
#  'process',
#  'proxi',
#  'ftp_proxi',
#  'rsync_proxi',
#  'no_proxi',
#  'test',
#  'autom',
#  'test',
#  'written',
#  'serverspec',
#  'vagrantserverspec',
#  'plugin',
#  'vagrant',
#  'plugin',
#  'vagrantserverspec',
#  'binbox',
#  'subcommand',
#  'run',
#  'autom',
#  'test',
#  'perform',
#  'exploratori',
#  'test',
#  'binbox',
#  'test',
#  'subcommand',
#  'autom',
#  'serverspec',
#  'test',
#  'exampl',
#  'execut',
#  'test',
#  '2004',
#  'box',
#  'virtualbox',
#  'follow',
#  'binbox',
#  'test',
#  'ubuntu2004',
#  'virtualbox',
#  'similarli',
#  'perform',
#  'exploratori',
#  'test',
#  'virtualbox',
#  'via',
#  'ssh',
#  'follow',
#  'binbox',
#  'ssh',
#  'ubuntu2004',
#  'virtualbox',
#  'variabl',
#  'overrid',
#  'sever',
#  'variabl',
#  'overrid',
#  'set',
#  'box',
#  'process',
#  'variabl',
#  'current',
#  'cpu',
#  'disk_siz',
#  'memori',
#  'variabl',
#  'headless',
#  'packer',
#  'headless',
#  'mode',
#  'headless',
#  'true',
#  'fals',
#  'variabl',
#  'perform',
#  'os',
#  'patch',
#  'manag',
#  'appli',
#  'os',
#  'updat',
#  'true',
#  'latest',
#  'os',
#  'updat',
#  'appli',
#  'variabl',
#  'packer',
#  'path',
#  'packer',
#  'binari',
#  'packer',
#  'variabl',
#  'iso_path',
#  'path',
#  'directori',
#  'os',
#  'imag',
#  'overrid',
#  'commonli',
#  'speed',
#  'packer',
#  'build',
#  'point',
#  'predownload',
#  'iso',
#  'instead',
#  'internet',
#  'url',
#  'variabl',
#  'ssh_usernam',
#  'ssh_password',
#  'chang',
#  'name',
#  'password',
#  'vagrantvagr',
#  'respect',
#  'variabl',
#  'install_vagrant_key',
#  'turn',
#  'instal',
#  'insecur',
#  'vagrant',
#  'key',
#  'outsid',
#  'vagrant',
#  'install_vagrant_key',
#  'fals',
#  'true',
#  'variabl',
#  'custom_script',
#  'specifi',
#  'custom',
#  'execut',
#  'add',
#  'scriptcustom',
#  'directori',
#  'content',
#  'ignor',
#  'customscriptsh',
#  'noth',
#  'contribut',
#  'fork',
#  'clone',
#  'repo',
#  '2',
#  'new',
#  'branch',
#  'pleas',
#  'dont',
#  'work',
#  'master',
#  'branch',
#  'directli',
#  '3',
#  'add',
#  'new',
#  'serverspec',
#  '4',
#  'fix',
#  'stuff',
#  'ssh',
#  'interact',
#  'test',
#  'box',
#  'like',
#  'sshvirtualboxubuntu2004',
#  '5',
#  'test',
#  'relev',
#  'templat',
#  'like',
#  'testvirtualboxubuntu2004',
#  'see',
#  'test',
#  'pass',
#  'repeat',
#  'step',
#  '35',
#  'done',
#  '6',
#  'readmemd',
#  'author',
#  'reflect',
#  'chang',
#  '7',
#  'larg',
#  'chang',
#  'mind',
#  'still',
#  'prefer',
#  'split',
#  'small',
#  'commit',
#  'good',
#  'commit',
#  'messag',
#  'import',
#  'documentatproject',
#  'nice',
#  'guidelin',
#  'write',
#  'descript',
#  'commit',
#  'messag',
#  '8',
#  'push',
#  'fork',
#  'submit',
#  'pull',
#  'request',
#  '9',
#  'submit',
#  'full',
#  'test',
#  'perform',
#  'chang',
#  'farm',
#  'notifi',
#  'test',
#  'suit',
#  'fail',
#  'would',
#  'like',
#  'help',
#  'contact',
#  'moujanannawakecom',
#  'acknowledg',
#  'parallel',
#  'softwar',
#  'basebox',
#  'farm',
#  'img',
#  'src',
#  'smartystreet',
#  'img',
#  'src',
#  'deepin',
#  'wine',
#  'deepinwin',
#  'ubuntudebian',
#  'deepin',
#  'giteegithubgite',
#  'gpl1726509538qqcom',
#  'ubuntudebian',
#  '21819',
#  'bug',
#  'releas',
#  'bash',
#  'wget',
#  'qo',
#  'ubuntudebian',
#  'clone',
#  'clone',
#  'releasesgithub',
#  'gite',
#  'installsh',
#  'kdex',
#  'kdeinstallsh',
#  'deepinwine21822ubuntu',
#  'install_2822sh',
#  '2',
#  'deepinwin',
#  'dpkg',
#  'deepin',
#  'qq',
#  '2',
#  'tim',
#  '3',
#  'qq',
#  '4',
#  '5',
#  'foxmail',
#  '6',
#  '7',
#  '360',
#  '8',
#  'winrar',
#  '9',
#  '10',
#  'deepinwin',
#  'qq',
#  '2',
#  'tim',
#  '3',
#  'qq',
#  '4',
#  '5',
#  'foxmail',
#  '6',
#  '7',
#  '360',
#  '8',
#  'winrar',
#  '9',
#  '1kdekd',
#  'neonkubuntu',
#  '180418011802kde',
#  '2',
#  '3',
#  '1804',
#  'gnome',
#  'gnome',
#  'shell',
#  'topicon',
#  'plu',
#  '4tim',
#  'flash',
#  'install_flash_player_ppapiex',
#  '2',
#  'deepinwinedeepintimdrive_c',
#  'tim',
#  'wine',
#  'c',
#  '3',
#  'termin',
#  'wineprefixdeepinwinedeepintim',
#  'deepinwin',
#  'cinstall_flash_player_ppapiex',
#  'tim',
#  '5winecfg',
#  'wineprefixdeepinwin',
#  'deepinwin',
#  'winecfg',
#  '6',
#  'optdeepinwinetoolsrunsh',
#  'wine_cmd',
#  'wine_cmdlc_allzh_cnutf8',
#  'deepinwin',
#  '7',
#  'uninstallsh',
#  '8',
#  'wget',
#  'qo',
#  '9',
#  'deepindeepin',
#  'deepinwin',
#  '10wine',
#  'xdotool',
#  'shell',
#  'apt',
#  'noinstallrecommend',
#  'xdotool',
#  '2',
#  'xdotool',
#  'wine',
#  'xdotool',
#  'wine',
#  'open_wechatsh',
#  'shell',
#  'binsh',
#  'wechatexectrlaltw',
#  'wechatwechatex',
#  'xdotool',
#  'key',
#  'window',
#  'xdotool',
#  'search',
#  'limit',
#  'pid',
#  'pgrep',
#  'wechatex',
#  'ctrlaltw',
#  'shell',
#  'chmod',
#  'x',
#  'open_wechatsh',
#  '3',
#  '4',
#  '11',
#  'shell',
#  'libjpeg62i386',
#  'fork',
#  '2',
#  'feat_xxx',
#  '3',
#  '4',
#  'pull',
#  'request',
#  '5',
#  'deepin',
#  'dockerubuntuvncdesktop',
#  'docker',
#  'pull',
#  'docker',
#  'star',
#  'dockerubuntuvncdesktop',
#  'docker',
#  'provid',
#  'web',
#  'vnc',
#  'interfac',
#  'access',
#  'lxdelxqt',
#  'desktop',
#  'environ',
#  'import',
#  'toc',
#  'cmdtoc',
#  'depthfrom2',
#  'depthto2',
#  'orderedlistfals',
#  'code_chunk_output',
#  'quick',
#  'startquickstart',
#  'vnc',
#  'viewervncview',
#  'sslssl',
#  'screen',
#  'resolutionscreenresolut',
#  'desktop',
#  'userdefaultdesktopus',
#  'deploy',
#  'subdirectori',
#  'rel',
#  'url',
#  'rootdeploytoasubdirectoryrelativeurlroot',
#  'sound',
#  'preview',
#  'onlysoundpreviewversionandlinuxonli',
#  'gener',
#  'dockerfil',
#  'jinja',
#  'templategeneratedockerfilefromjinjatempl',
#  'troubleshoot',
#  'faqtroubleshootingandfaq',
#  'licenselicens',
#  'code_chunk_output',
#  'quick',
#  'start',
#  'docker',
#  'contain',
#  'access',
#  'port',
#  '6080',
#  'shell',
#  'docker',
#  'p',
#  '608080',
#  'v',
#  'devshmdevshm',
#  'dorowuubuntudesktoplxdevnc',
#  'brows',
#  'img',
#  'src',
#  'flavor',
#  'choos',
#  'favorit',
#  'tag',
#  'focal',
#  '2004',
#  'latest',
#  'focallxqt',
#  '2004',
#  'lxqt',
#  'bionic',
#  '1804',
#  'bioniclxqt',
#  '1804',
#  'lxqt',
#  'xenial',
#  '1604',
#  'deprec',
#  'trusti',
#  '1404',
#  'deprec',
#  'vnc',
#  'viewer',
#  'forward',
#  'vnc',
#  'servic',
#  'port',
#  '5900',
#  'host',
#  'shell',
#  'docker',
#  'p',
#  '608080',
#  'p',
#  '59005900',
#  'v',
#  'devshmdevshm',
#  'dorowuubuntudesktoplxdevnc',
#  'open',
#  'vnc',
#  'viewer',
#  'connect',
#  'port',
#  '5900',
#  'would',
#  'like',
#  'protect',
#  'vnc',
#  'servic',
#  'password',
#  'environ',
#  'variabl',
#  'vnc_password',
#  'exampl',
#  'shell',
#  'docker',
#  'p',
#  '608080',
#  'p',
#  '59005900',
#  'e',
#  'vnc_passwordmypassword',
#  'v',
#  'devshmdevshm',
#  'dorowuubuntudesktoplxdevnc',
#  'prompt',
#  'ask',
#  'password',
#  'either',
#  'browser',
#  'vnc',
#  'viewer',
#  'provid',
#  'base',
#  'access',
#  'authent',
#  'shell',
#  'docker',
#  'p',
#  '608080',
#  'e',
#  'ssl',
#  'connect',
#  'ssl',
#  'gener',
#  'self',
#  'sign',
#  'ssl',
#  'certif',
#  'first',
#  'dont',
#  'shell',
#  'mkdir',
#  'p',
#  'ssl',
#  'openssl',
#  'req',
#  'x509',
#  'node',
#  'day',
#  '365',
#  'newkey',
#  'rsa2048',
#  'keyout',
#  'sslnginxkey',
#  'sslnginxcrt',
#  'specifi',
#  'ssl',
#  'port',
#  'ssl_port',
#  'certif',
#  'path',
#  'etcnginxssl',
#  'forward',
#  '6081',
#  'shell',
#  'docker',
#  'p',
#  '6081443',
#  'e',
#  'ssl_port443',
#  'v',
#  'pwdssletcnginxssl',
#  'v',
#  'devshmdevshm',
#  'dorowuubuntudesktoplxdevnc',
#  'screen',
#  'resolut',
#  'resolut',
#  'virtual',
#  'desktop',
#  'adapt',
#  'browser',
#  'window',
#  'size',
#  'first',
#  'connect',
#  'may',
#  'choos',
#  'fix',
#  'resolut',
#  'pass',
#  'resolut',
#  'environ',
#  'variabl',
#  'exampl',
#  'shell',
#  'docker',
#  'p',
#  '608080',
#  'e',
#  'resolution1920x1080',
#  'v',
#  'devshmdevshm',
#  'dorowuubuntudesktoplxdevnc',
#  'desktop',
#  'may',
#  'chang',
#  'password',
#  'respect',
#  'password',
#  'environ',
#  'variabl',
#  'exampl',
#  'shell',
#  'docker',
#  'p',
#  '608080',
#  'e',
#  'userdoro',
#  'e',
#  'passwordpassword',
#  'v',
#  'devshmdevshm',
#  'dorowuubuntudesktoplxdevnc',
#  'deploy',
#  'subdirectori',
#  'rel',
#  'url',
#  'may',
#  'deploy',
#  'applic',
#  'subdirectori',
#  'exampl',
#  'someprefix',
#  'access',
#  'applic',
#  'shell',
#  'docker',
#  'p',
#  '608080',
#  'e',
#  'relative_url_rootsomeprefix',
#  'dorowuubuntudesktoplxdevnc',
#  'note',
#  'variabl',
#  'lead',
#  'trail',
#  'splash',
#  'sound',
#  'preview',
#  'work',
#  'first',
#  'insert',
#  'modul',
#  'sndaloop',
#  'specifi',
#  '2',
#  'index',
#  'sound',
#  'loop',
#  'devic',
#  'shell',
#  'modprob',
#  'sndaloop',
#  'index2',
#  'start',
#  'contain',
#  'shell',
#  'docker',
#  'rm',
#  'p',
#  '608080',
#  'devic',
#  'devsnd',
#  'e',
#  'alsadevhw20',
#  'dorowuubuntudesktoplxdevnc',
#  'devic',
#  'devsnd',
#  'e',
#  'alsadevhw20',
#  'mean',
#  'grant',
#  'sound',
#  'devic',
#  'contain',
#  'basic',
#  'asla',
#  'config',
#  'card',
#  '2',
#  'launch',
#  'browser',
#  'url',
#  'follow',
#  'screen',
#  'captur',
#  'oper',
#  'turn',
#  'sound',
#  'end',
#  'video',
#  'demo',
#  'video',
#  'gener',
#  'dockerfil',
#  'jinja',
#  'templat',
#  'warn',
#  'deprec',
#  'dockerfil',
#  'configur',
#  'gener',
#  'templat',
#  'one',
#  'amd64',
#  'armhf',
#  'flavor',
#  'refer',
#  'flavorflavoryml',
#  'base',
#  'desktop',
#  'desktop',
#  'environ',
#  'flavor',
#  'addon_packag',
#  'flavor',
#  'dockerfil',
#  'configur',
#  'regener',
#  'exist',
#  'may',
#  'forc',
#  'regener',
#  'remov',
#  'clean',
#  'troubleshoot',
#  'faq',
#  'boot2dock',
#  'connect',
#  'issu',
#  '2',
#  'multilanguag',
#  'support',
#  '3',
#  'autostart',
#  '4',
#  'x11vnc',
#  'argumentsmultiptr',
#  '5',
#  'firefoxchrom',
#  'crash',
#  'devshm',
#  '6',
#  'resiz',
#  'display',
#  'size',
#  'without',
#  'destroy',
#  'contain',
#  'licens',
#  'see',
#  'licens',
#  'detail',
#  'docker',
#  'i386',
#  'buildimagesh',
#  'docker',
#  '32bitubuntu1604',
#  'see',
#  'also',
#  'deprec',
#  'cookbook',
#  'deprec',
#  'instead',
#  'apt_repositori',
#  'local',
#  'resourc',
#  'built',
#  'chef',
#  'infra',
#  'client',
#  'manag',
#  'system',
#  'cookbook',
#  'statu',
#  'set',
#  'apt',
#  'sourc',
#  'manag',
#  'local',
#  'set',
#  'requir',
#  'platform',
#  'chef',
#  'chef',
#  '13',
#  'cookbook',
#  'none',
#  'attribut',
#  'see',
#  'attributesdefaultrb',
#  'valu',
#  'nodeubuntuarchive_url',
#  ...]

# %%
u_count = pd.Series(ubuntu_corpus_list)

# %%
u_count.value_counts().nlargest(20)
# Out:
# docker      1763
# bash        1473
# instal      1316
# e           1283
# de          1246
# contain     1129
# ensur       1107
# work        1102
# follow      1067
# chang       1052
# 2           1031
# autom       1029
# support      998
# configur     956
# start        952
# test         943
# file         931
# run          930
# name         901
# gener        893
# dtype: int64

# %%
#adding the clean function through the readme content and adding 
#onto a new column in the df:
ubuntu['clean_readme'] = ubuntu.readme_contents.apply(clean_data)
ubuntu
# Out:
#                                            repo language  \
# 0                             dockerfile/ubuntu    Shell
# 1                              boxcutter/ubuntu    Shell
# 2                   wszqkzqk/deepin-wine-ubuntu        C
# 3                fcwu/docker-ubuntu-vnc-desktop     HTML
# 4                           docker-32bit/ubuntu    Shell
# ...                                         ...      ...
# 1095                  kurniawandata/nasihosting      PHP
# 1096             mastermindg/trac-docker-ubuntu    Shell
# 1097              hortonworks/docker-protractor    Shell
# 1098                    rubiojr/surface3-kernel        C
# 1099  sh0rez/vSphere-terraform_ubuntu-cloud-ova      HCL
#
#                                         readme_contents  \
# 0     ## Ubuntu Dockerfile\n\n\nThis repository cont...
# 1     # Packer templates for Ubuntu written in legac...
# 2     # Deepin wine for Ubuntu and Debian\n\n## 一、项目...
# 3     # docker-ubuntu-vnc-desktop\n\n[![Docker Pulls...
# 4     ubuntu\n======\n\nBuild a docker image for ubu...
# ...                                                 ...
# 1095  # nasihosting\n\nNasihosting v5.2\n-----------...
# 1096  # trac-ubuntu\n\n[![](https://images.microbadg...
# 1097  **General Docker image for executing headless ...
# 1098          Linux kernel release 3.x <http://kerne...
# 1099  # :cloud: vSphere Terraform Ubuntu-cloud OVA/O...
#
#                                            clean_readme
# 0     dockerfil repositori contain dockerfil base do...
# 1     packer templat written legaci json overview re...
# 2     deepin wine deepinwin ubuntudebian deepin gite...
# 3     dockerubuntuvncdesktop docker pull docker star...
# 4     docker i386 buildimagesh docker 32bitubuntu160...
# ...                                                 ...
# 1095  nasihost nasihost v52 alt text untuk mendukung...
# 1096  tracubuntu docker hub repo build docker contai...
# 1097  gener docker execut headless googl chrome fire...
# 1098  releas 3x releas note 3 read care tell explain...
# 1099  cloud vsphere terraform ubuntucloud ovaovf rep...
#
# [964 rows x 4 columns]

# %% [markdown]
# ______________________________

# %% [markdown]
# ## Creating a df for the top 10 languages:

# %%
#finding all shell readmes:
shell_readme =' '.join(ubuntu[ubuntu['language'] == 'Shell'].clean_readme)

# %%
ubuntu[ubuntu['language'] == 'Shell'].clean_readme
# Out:
# 0       dockerfil repositori contain dockerfil base do...
# 1       packer templat written legaci json overview re...
# 4       docker i386 buildimagesh docker 32bitubuntu160...
# 6       termuxubuntu chroot termux wget proot termux p...
# 8       shadowsock auto shadowsock shadowsockssh auto ...
#                               ...
# 1091    debianubuntu loung href altbuild statu src rep...
# 1093    minecraftinitscript jami bainbridg jamiebainbr...
# 1094    wsl dotfil simpl dotfil script setup _window s...
# 1096    tracubuntu docker hub repo build docker contai...
# 1097    gener docker execut headless googl chrome fire...
# Name: clean_readme, Length: 502, dtype: object

# %%
#renaming to shell words and cleaning data:
shell_words=clean_data(shell_readme)

# %%
#finding all python readmes:
python_readme =' '.join(ubuntu[ubuntu['language'] == 'Python'].clean_readme)

# %%
#renaming to python words and cleaning data:
python_words=clean_data(python_readme)

# %%
#finding all dockerfile readmes:
dockerfile_readme =' '.join(ubuntu[ubuntu['language'] == 'Dockerfile'].clean_readme)

# %%
#renaming to dockerfile words and cleaning data:
dockerfile_words=clean_data(dockerfile_readme)

# %%
#finding all C readmes:
C_readme =' '.join(ubuntu[ubuntu['language'] == 'C'].clean_readme)

# %%
#renaming to C words and cleaning data:
C_words=clean_data(C_readme)

# %%
#finding all C ++ readmes:
Cplus_readme =' '.join(ubuntu[ubuntu['language'] == 'C++'].clean_readme)

# %%
#renaming to C++ words and cleaning data:
Cplus_words=clean_data(Cplus_readme)

# %% [markdown]
# ### Finding word frequencies per language:

# %%
#creating series with frequencies by putting the clean_readme strings
#as series (but use split to split up words into a list)

shell_freq = pd.Series(shell_words.split()).value_counts()
python_freq = pd.Series(python_words.split()).value_counshets()
dockerfile_freq = pd.Series(dockerfile_words.split()).value_counts()
C_freq = pd.Series(C_words.split()).value_counts()
Cplus_freq = pd.Series(Cplus_words.split()).value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/d3/11nygz6126ndxvtrp12687680000gn/T/ipykernel_20454/3553845465.py in <module>
#       3
#       4 shell_freq = pd.Series(shell_words.split()).value_counts()
# ----> 5 python_freq = pd.Series(python_words.split()).value_counshets()
#       6 dockerfile_freq = pd.Series(dockerfile_words.split()).value_counts()
#       7 C_freq = pd.Series(C_words.split()).value_counts()
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'value_counshets'

# %%
#looking at how we need to split:
pd.Series(shell_words.split()).value_counts()
# Out:
# de               1227
# e                1059
# bash              794
# video             773
# instal            734
#                  ...
# xlm                 1
# tether              1
# usdt                1
# bch                 1
# ubuntuservers       1
# Length: 22346, dtype: int64

# %%
#combining frequencies into dataframes:
word_counts = (pd.concat([shell_freq, python_freq, dockerfile_freq, C_freq, Cplus_freq], axis=1, sort=True)
              .set_axis(['shell','python','dockerfile','C','Cplus'], axis=1, inplace=False)
              .fillna(0)
              .apply(lambda s: s.astype(int)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/d3/11nygz6126ndxvtrp12687680000gn/T/ipykernel_20454/484299052.py in <module>
#       1 #combining frequencies into dataframes:
# ----> 2 word_counts = (pd.concat([shell_freq, python_freq, dockerfile_freq, C_freq, Cplus_freq], axis=1, sort=True)
#       3               .set_axis(['shell','python','dockerfile','C','Cplus'], axis=1, inplace=False)
#       4               .fillna(0)
#       5               .apply(lambda s: s.astype(int)))
#
# NameError: name 'python_freq' is not defined

# %%
word_counts.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/d3/11nygz6126ndxvtrp12687680000gn/T/ipykernel_20454/1373847304.py in <module>
# ----> 1 word_counts.head()
#
# NameError: name 'word_counts' is not defined

# %% [markdown]
# ### What are the most occuring words across these languages?

# %%
word_counts.sort_values(by='shell', ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/d3/11nygz6126ndxvtrp12687680000gn/T/ipykernel_20454/1100361335.py in <module>
# ----> 1 word_counts.sort_values(by='shell', ascending=False).head(10)
#
# NameError: name 'word_counts' is not defined

# %% [markdown]
# ___________________________________

# %% [markdown]
# ## How long is a typical Ubuntu Readme (after clean)?

# %%
#creating a column that gives the lenght of the readme_contents after clean_data function
ubuntu['length_of_readme'] = ubuntu['readme_contents'].apply(lambda r : len(clean_data(r)))

# %%
#plotting this to show any anomalies:
plt.figure(figsize = (10,10))
sns.boxplot(data = ubuntu.length_of_readme)
# Out:
# <AxesSubplot:>

# %%
#finding the mean, min and max of Ubuntu readmes:
ubuntu.length_of_readme.describe()
# Out:
# count       964.00000
# mean       2532.25000
# std        6611.96954
# min           0.00000
# 25%         350.50000
# 50%        1006.00000
# 75%        2239.00000
# max      147543.00000
# Name: length_of_readme, dtype: float64

# %%
#longest readme info:
ubuntu[ubuntu['length_of_readme'] == 147543]
# Out:
#                                      repo          language  \
# 1062  shaohua0116/ICLR2020-OpenReviewData  Jupyter Notebook
#
#                                         readme_contents  \
# 1062  # Crawl and Visualize ICLR 2020 OpenReview Dat...
#
#                                            clean_readme  length_of_readme
# 1062  crawl visual iclr 2020 openreview data p align...            147543

# %%
#minimum readmes:
ubuntu[ubuntu['length_of_readme'] == 0]
# Out:
#                                         repo    language readme_contents  \
# 35               ErickWendel/ew-ubuntu-setup       Shell
# 74                  officialputuid/UbuntuSSH       Shell
# 135              ErickWendel/ew-ubuntu-setup       Shell
# 174                 officialputuid/UbuntuSSH       Shell
# 263                              till/ubuntu       Shell
# 284                 Sushrut1101/Ubuntu-Tmate       Shell
# 303          sandheepgr/ubuntu-customization       Shell
# 454             umangv/indicator-stickynotes      Python
# 621                       lxc/lxc-pkg-ubuntu           C
# 735          ubuntu-mate/ubuntu-mate-artwork       Shell
# 740                    ElectroPerf/UbuntuSSH       Shell
# 763          tseliot/nvidia-graphics-drivers           C
# 850   friendlyarm/build-env-on-ubuntu-bionic       Shell
# 854     ubports/initramfs-tools-ubuntu-touch       Shell
# 908           fshchudlo/netcore-ubuntu-setup       Shell
# 979        mobingidocker/ubuntu-apache2-php7       Shell
# 1008                   zakuradev/xrdp-ubuntu       Shell
# 1067          allankevinrichie/vfs495_ubuntu           C
# 1074          linshufei/UbuntuReceivePicture         C++
# 1076                           costales/unav  JavaScript
#
#      clean_readme  length_of_readme
# 35                                0
# 74                                0
# 135                               0
# 174                               0
# 263                               0
# 284                               0
# 303                               0
# 454                               0
# 621                               0
# 735                               0
# 740                               0
# 763                               0
# 850                               0
# 854                               0
# 908                               0
# 979                               0
# 1008                              0
# 1067                              0
# 1074                              0
# 1076                              0

# %%
ubuntu['cleaned_length'] = 0

# %%
plt.figure(figsize=(18, 8))
sns.barplot(data = ubuntu.groupby('language').mean().reset_index().sort_values('length_of_readme', ascending=False), x = 'length_of_readme', y='language')
plt.title('Average Readme length by Language')
plt.show()

# %% [markdown]
# _____________________________________________

# %% [markdown]
# ## Number of unique words in Ubuntu Repos:

# %%
ubuntu_corpus_series = pd.Series(ubuntu_corpus_list)
pd.Series(ubuntu_corpus_list).nunique()
# Out:
# 43230

# %% [markdown]
# ___________________________________________

# %% [markdown]
# ## Most common bigrams of Ubuntu:

# %%
ubuntu_bigrams = (pd.Series(nltk.ngrams(ubuntu_corpus_series, 2)).value_counts().head(20))

# %%
ubuntu_bigrams
# Out:
# (math, librari)               322
# (intelr, math)                320
# (neural, network)             310
# (tr, tr)                      249
# (link, da)                    226
# (video, aula)                 224
# (da, video)                   222
# (ness, video)                 220
# (tdtd, aligncentersupport)    219
# (environ, variabl)            193
# (aligncentersupport, tdtd)    187
# (librari, 2017)               183
# (de, configuracao)            162
# (2004x, lt)                   156
# (reinforc, learn)             149
# (tdtd, aligncenternot)        145
# (aligncenternot, support)     145
# (librari, 2018)               137
# (de, 2004x)                   136
# (gnulinux, 1804x)             130
# dtype: int64

# %% [markdown]
# ## Most common trigrams of Ubuntu:

# %%
ubuntu_trigrams = (pd.Series(nltk.ngrams(ubuntu_corpus_series, 3)).value_counts().head(20))
ubuntu_trigrams
# Out:
# (intelr, math, librari)                           320
# (da, video, aula)                                 222
# (link, da, video)                                 222
# (math, librari, 2017)                             183
# (tdtd, aligncentersupport, tdtd)                  168
# (tdtd, aligncenternot, support)                   145
# (math, librari, 2018)                             137
# (de, 2004x, lt)                                   136
# (aligncenternot, support, tdtd)                   129
# (gnulinux, 1804x, lt)                             128
# (2004x, lt, devop)                                122
# (lt, devop, shell)                                118
# (curso, gratuito, de)                             116
# (shell, ness, video)                              116
# (ness, video, vou)                                116
# (devop, shell, ness)                              116
# (gratuito, de, 2004x)                             116
# (aligncentersupport, tdtd, aligncentersupport)    112
# (utilizado, ness, video)                          104
# (video, mostrando, os)                            104
# dtype: int64

# %%
from wordcloud import WordCloud

img = WordCloud(background_color='white').generate(ubuntu_bigrams)
# WordCloud() produces an image object, which can be displayed with plt.imshow
plt.imshow(img)
# axis aren't very useful for a word cloud
plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/d3/11nygz6126ndxvtrp12687680000gn/T/ipykernel_20454/2721010180.py in <module>
#       1 from wordcloud import WordCloud
#       2
# ----> 3 img = WordCloud(background_color='white').generate(ubuntu_bigrams)
#       4 # WordCloud() produces an image object, which can be displayed with plt.imshow
#       5 plt.imshow(img)
#
# /usr/local/anaconda3/lib/python3.9/site-packages/wordcloud/wordcloud.py in generate(self, text)
#     637         self
#     638         """
# --> 639         return self.generate_from_text(text)
#     640
#     641     def _check_generated(self):
#
# /usr/local/anaconda3/lib/python3.9/site-packages/wordcloud/wordcloud.py in generate_from_text(self, text)
#     618         self
#     619         """
# --> 620         words = self.process_text(text)
#     621         self.generate_from_frequencies(words)
#     622         return self
#
# /usr/local/anaconda3/lib/python3.9/site-packages/wordcloud/wordcloud.py in process_text(self, text)
#     580         regexp = self.regexp if self.regexp is not None else pattern
#     581
# --> 582         words = re.findall(regexp, text, flags)
#     583         # remove 's
#     584         words = [word[:-2] if word.lower().endswith("'s") else word
#
# /usr/local/anaconda3/lib/python3.9/re.py in findall(pattern, string, flags)
#     239
#     240     Empty matches are included in the result."""
# --> 241     return _compile(pattern, flags).findall(string)
#     242
#     243 def finditer(pattern, string, flags=0):
#
# TypeError: expected string or bytes-like object

# %% [markdown]
# ________________________________________________

# %% [markdown]
# ## Reading in the master list csv:

# %%
master_df = pd.read_csv('master_list.csv')

# %%
master_df
# Out:
#                                 repo language  \
# 0                  dockerfile/ubuntu    Shell
# 1                   boxcutter/ubuntu    Shell
# 2        wszqkzqk/deepin-wine-ubuntu        C
# 3     fcwu/docker-ubuntu-vnc-desktop     HTML
# 4                docker-32bit/ubuntu    Shell
# ...                              ...      ...
# 3295        gmas/home-router-ansible     Ruby
# 3296                  Voltasalt/tial    Shell
# 3297           Caesim404/sikulix-git    Shell
# 3298          danboid/ZALARM-install      NaN
# 3299               BiteDasher/pacadd    Shell
#
#                                         readme_contents  distro
# 0     ## Ubuntu Dockerfile\n\n\nThis repository cont...  ubuntu
# 1     # Packer templates for Ubuntu written in legac...  ubuntu
# 2     # Deepin wine for Ubuntu and Debian\n\n## 一、项目...  ubuntu
# 3     # docker-ubuntu-vnc-desktop\n\n[![Docker Pulls...  ubuntu
# 4     ubuntu\n======\n\nBuild a docker image for ubu...  ubuntu
# ...                                                 ...     ...
# 3295  # home-router-ansible\nAnsible scripts for set...    arch
# 3296      # tial\nTwitch Installs Arch Linux: Scripts\n    arch
# 3297                                                NaN    arch
# 3298  # Installing Arch Linux ARM (ALARM) on the SHA...    arch
# 3299  # pacadd\nA simple tool for managing repositor...    arch
#
# [3300 rows x 4 columns]

# %% [markdown]
# ### Exploring the data:

# %%
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3300 entries, 0 to 3299
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   repo             3300 non-null   object
#  1   language         2936 non-null   object
#  2   readme_contents  3148 non-null   object
#  3   distro           3300 non-null   object
# dtypes: object(4)
# memory usage: 103.2+ KB

# %%
master_df.info
# Out:
# <bound method DataFrame.info of                                 repo language  \
# 0                  dockerfile/ubuntu    Shell
# 1                   boxcutter/ubuntu    Shell
# 2        wszqkzqk/deepin-wine-ubuntu        C
# 3     fcwu/docker-ubuntu-vnc-desktop     HTML
# 4                docker-32bit/ubuntu    Shell
# ...                              ...      ...
# 3295        gmas/home-router-ansible     Ruby
# 3296                  Voltasalt/tial    Shell
# 3297           Caesim404/sikulix-git    Shell
# 3298          danboid/ZALARM-install      NaN
# 3299               BiteDasher/pacadd    Shell
#
#                                         readme_contents  distro
# 0     ## Ubuntu Dockerfile\n\n\nThis repository cont...  ubuntu
# 1     # Packer templates for Ubuntu written in legac...  ubuntu
# 2     # Deepin wine for Ubuntu and Debian\n\n## 一、项目...  ubuntu
# 3     # docker-ubuntu-vnc-desktop\n\n[![Docker Pulls...  ubuntu
# 4     ubuntu\n======\n\nBuild a docker image for ubu...  ubuntu
# ...                                                 ...     ...
# 3295  # home-router-ansible\nAnsible scripts for set...    arch
# 3296      # tial\nTwitch Installs Arch Linux: Scripts\n    arch
# 3297                                                NaN    arch
# 3298  # Installing Arch Linux ARM (ALARM) on the SHA...    arch
# 3299  # pacadd\nA simple tool for managing repositor...    arch
#
# [3300 rows x 4 columns]>

# %%
master_df.describe()
# Out:
#                              repo language  \
# count                        3300     2936
# unique                       2896       61
# top     angristan/openvpn-install    Shell
# freq                            6     1679
#
#                                           readme_contents  distro
# count                                                3148    3300
# unique                                               2742       3
# top     # openvpn-install\n\n![Test](https://github.co...  ubuntu
# freq                                                    6    1100

# %%
#any nulls?
master_df.isnull().sum()
# Out:
# repo                 0
# language           364
# readme_contents    152
# distro               0
# dtype: int64

# %%
#dropping nulls:
master_df = master_df.dropna()

# %%
#just checking if worked:
master_df.isnull().sum()
# Out:
# repo               0
# language           0
# readme_contents    0
# distro             0
# dtype: int64

# %% [markdown]
# ## Looking at top languages across master_list:

# %%
#looking at the overall percentages of the top 10 languages used in all repos:
master_language_counts=master_df.language.value_counts(normalize=True).head(10)
master_language_counts
# Out:
# Shell         0.569697
# Python        0.103030
# C             0.050267
# Dockerfile    0.035294
# C++           0.022460
# HTML          0.021034
# JavaScript    0.018895
# Makefile      0.018538
# CSS           0.017112
# Ruby          0.017112
# Name: language, dtype: float64

# %%
#creating a df of the percentages to prep for charts:
temp = pd.DataFrame({'language' : master_language_counts.index, 'percentage': master_language_counts.values})
temp
# Out:
#      language  percentage
# 0       Shell    0.569697
# 1      Python    0.103030
# 2           C    0.050267
# 3  Dockerfile    0.035294
# 4         C++    0.022460
# 5        HTML    0.021034
# 6  JavaScript    0.018895
# 7    Makefile    0.018538
# 8         CSS    0.017112
# 9        Ruby    0.017112

# %%
#plotting out the percentages of the Top 10 languages used in Ubuntu repos:
plt.figure(figsize=(10,8))
sns.barplot(data=temp, x = 'language', y = 'percentage')
# Out:
# <AxesSubplot:xlabel='language', ylabel='percentage'>

# %% [markdown]
# ## Finding common words overall for stop_words:

# %%
#grabbing text from df:
master_corpus = ' '.join(master_df['readme_contents'])
master_corpus[:100]
# Out:
# '## Ubuntu Dockerfile\n\n\nThis repository contains **Dockerfile** of [Ubuntu](http://www.ubuntu.com/) f'

# %%
#first, lower all letters:
master_corpus = master_corpus.lower()

# %%
#next, normalize by removing special characters:
import unicodedata

master_corpus = unicodedata.normalize('NFKD', master_corpus)\
    .encode('ascii', 'ignore')\
    .decode('utf-8', 'ignore')

# %%
#taking out special characters:
# remove anything that is not a through z, a number, a single quote, or whitespace
master_corpus = re.sub(r"[^a-z0-9'\s]", '', master_corpus)

# %%
#tokenizing:
import nltk
tokenizer = nltk.tokenize.ToktokTokenizer()

print(tokenizer.tokenize(master_corpus, return_str=True)[0:500])
# Out:
# ubuntu dockerfile
#
#
# this repository contains dockerfile of ubuntuhttpwwwubuntucom for dockerhttpswwwdockercom ' s automated buildhttpsregistryhubdockercomudockerfileubuntu published to the public docker hub registryhttpsregistryhubdockercom
#
#
#  base docker image
#
#  ubuntu1404httpsregistryhubdockercomulibraryubuntu
#
#
#  installation
#
# 1 install dockerhttpswwwdockercom
#
# 2 download automated buildhttpsregistryhubdockercomudockerfileubuntu from public docker hub registryhttpsregistryhubdockercom docker p

# %%
#removing main stopwords:
from nltk.corpus import stopwords
stopword_list = stopwords.words('english')

stopword_list.remove('no')
stopword_list.remove('not')

stopword_list[:10]
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]

# %%
#creating loop for this:
words = master_corpus.split()
filtered_words = [w for w in words if w not in stopword_list]

print('Removed {} stopwords'.format(len(words) - len(filtered_words)))
print('---')

corpus_without_stopwords = ' '.join(filtered_words)

print(corpus_without_stopwords)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
#creating a list 
master_corpus_list = corpus_without_stopwords.split()
master_corpus_list
# Out:
# ['ubuntu',
#  'dockerfile',
#  'repository',
#  'contains',
#  'dockerfile',
#  'ubuntuhttpwwwubuntucom',
#  "dockerhttpswwwdockercom's",
#  'automated',
#  'buildhttpsregistryhubdockercomudockerfileubuntu',
#  'published',
#  'public',
#  'docker',
#  'hub',
#  'registryhttpsregistryhubdockercom',
#  'base',
#  'docker',
#  'image',
#  'ubuntu1404httpsregistryhubdockercomulibraryubuntu',
#  'installation',
#  '1',
#  'install',
#  'dockerhttpswwwdockercom',
#  '2',
#  'download',
#  'automated',
#  'buildhttpsregistryhubdockercomudockerfileubuntu',
#  'public',
#  'docker',
#  'hub',
#  'registryhttpsregistryhubdockercom',
#  'docker',
#  'pull',
#  'dockerfileubuntu',
#  'alternatively',
#  'build',
#  'image',
#  'dockerfile',
#  'docker',
#  'build',
#  'tdockerfileubuntu',
#  'githubcomdockerfileubuntu',
#  'usage',
#  'docker',
#  'run',
#  'rm',
#  'dockerfileubuntu',
#  'packer',
#  'templates',
#  'ubuntu',
#  'written',
#  'legacy',
#  'json',
#  'overview',
#  'repository',
#  'contains',
#  'packerhttpspackerio',
#  'templates',
#  'creating',
#  'ubuntu',
#  'vagrant',
#  'boxes',
#  'written',
#  'legacy',
#  'json',
#  'current',
#  'boxes',
#  'no',
#  'longer',
#  'provide',
#  'prebuilt',
#  'binaries',
#  'templates',
#  'building',
#  'vagrant',
#  'boxes',
#  'packer',
#  'build',
#  'boxes',
#  'need',
#  'virtualboxhttpswwwvirtualboxorgwikidownloads',
#  'vmware',
#  'fusionhttpswwwvmwarecomproductsfusionvmware',
#  'workstationhttpswwwvmwarecomproductsworkstation',
#  'parallelshttpwwwparallelscomproductsdesktopwhatsnew',
#  'installed',
#  'parallels',
#  'requires',
#  'parallels',
#  'virtualization',
#  'sdk',
#  'machttpwwwparallelscomdownloadsdesktop',
#  'installed',
#  'additional',
#  'prerequisite',
#  'make',
#  'use',
#  'json',
#  'files',
#  'containing',
#  'user',
#  'variables',
#  'build',
#  'specific',
#  'versions',
#  'ubuntu',
#  'tell',
#  'packer',
#  'use',
#  'specific',
#  'user',
#  'variable',
#  'file',
#  'via',
#  'varfile',
#  'command',
#  'line',
#  'option',
#  'override',
#  'default',
#  'options',
#  'core',
#  'ubuntujson',
#  'packer',
#  'template',
#  'builds',
#  'ubuntu',
#  '2004',
#  'default',
#  'example',
#  'build',
#  'ubuntu',
#  '2004',
#  'use',
#  'following',
#  'packer',
#  'build',
#  'varfileubuntu2004json',
#  'ubuntujson',
#  'want',
#  'make',
#  'boxes',
#  'specific',
#  'desktop',
#  'virtualization',
#  'platform',
#  'use',
#  'parameter',
#  'example',
#  'build',
#  'ubuntu',
#  '2004',
#  'virtualbox',
#  'packer',
#  'build',
#  'onlyvirtualboxiso',
#  'varfileubuntu2004json',
#  'ubuntujson',
#  'boxcutter',
#  'templates',
#  'currently',
#  'support',
#  'following',
#  'desktop',
#  'virtualization',
#  'strings',
#  'parallelsiso',
#  'parallelshttpwwwparallelscomproductsdesktopwhatsnew',
#  'desktop',
#  'virtualization',
#  'requires',
#  'pro',
#  'edition',
#  'desktop',
#  'edition',
#  'work',
#  'virtualboxiso',
#  'virtualboxhttpswwwvirtualboxorgwikidownloads',
#  'desktop',
#  'virtualization',
#  'vmwareiso',
#  'vmware',
#  'fusionhttpswwwvmwarecomproductsfusion',
#  'vmware',
#  'workstationhttpswwwvmwarecomproductsworkstation',
#  'desktop',
#  'virtualization',
#  'building',
#  'vagrant',
#  'boxes',
#  'box',
#  'script',
#  "we've",
#  'also',
#  'provided',
#  'wrapper',
#  'script',
#  'binbox',
#  'ease',
#  'use',
#  'alternatively',
#  'use',
#  'following',
#  'build',
#  'ubuntu',
#  '2004',
#  'providers',
#  'binbox',
#  'build',
#  'ubuntu2004',
#  'want',
#  'build',
#  'ubuntu',
#  '2004',
#  'virtualbox',
#  'binbox',
#  'build',
#  'ubuntu2004',
#  'virtualbox',
#  'building',
#  'vagrant',
#  'boxes',
#  'makefile',
#  'gnu',
#  'make',
#  'makefile',
#  'drives',
#  'complete',
#  'basebox',
#  'creation',
#  'pipeline',
#  'following',
#  'stages',
#  'build',
#  'create',
#  'basebox',
#  'box',
#  'files',
#  'assure',
#  'verify',
#  'basebox',
#  'box',
#  'files',
#  'produced',
#  'function',
#  'correctly',
#  'deliver',
#  'upload',
#  'box',
#  'files',
#  'artifactoryhttpswwwjfrogcomconfluencedisplayrtfvagrantrepositories',
#  'atlashttpsatlashashicorpcom',
#  's3',
#  'buckethttpsawsamazoncoms3',
#  'pipeline',
#  'driven',
#  'via',
#  'following',
#  'targets',
#  'making',
#  'easy',
#  'include',
#  'favourite',
#  'ci',
#  'tool',
#  'make',
#  'build',
#  'build',
#  'available',
#  'box',
#  'types',
#  'make',
#  'assure',
#  'run',
#  'tests',
#  'boxes',
#  'make',
#  'deliver',
#  'upload',
#  'box',
#  'artifacts',
#  'repository',
#  'make',
#  'clean',
#  'clean',
#  'build',
#  'detritus',
#  'proxy',
#  'settings',
#  'templates',
#  'respect',
#  'following',
#  'network',
#  'proxy',
#  'environment',
#  'variables',
#  'forward',
#  'virtual',
#  'machine',
#  'environment',
#  'box',
#  'creation',
#  'process',
#  'using',
#  'proxy',
#  'httpproxy',
#  'httpsproxy',
#  'ftpproxy',
#  'rsyncproxy',
#  'noproxy',
#  'tests',
#  'automated',
#  'tests',
#  'written',
#  'serverspechttpserverspecorg',
#  'require',
#  'vagrantserverspec',
#  'plugin',
#  'installed',
#  'vagrant',
#  'plugin',
#  'install',
#  'vagrantserverspec',
#  'binbox',
#  'script',
#  'subcommands',
#  'running',
#  'automated',
#  'tests',
#  'performing',
#  'exploratory',
#  'testing',
#  'use',
#  'binbox',
#  'test',
#  'subcommand',
#  'run',
#  'automated',
#  'serverspec',
#  'tests',
#  'example',
#  'execute',
#  'tests',
#  'ubuntu',
#  '2004',
#  'box',
#  'virtualbox',
#  'use',
#  'following',
#  'binbox',
#  'test',
#  'ubuntu2004',
#  'virtualbox',
#  'similarly',
#  'perform',
#  'exploratory',
#  'testing',
#  'virtualbox',
#  'image',
#  'via',
#  'ssh',
#  'run',
#  'following',
#  'command',
#  'binbox',
#  'ssh',
#  'ubuntu2004',
#  'virtualbox',
#  'variable',
#  'overrides',
#  'several',
#  'variables',
#  'used',
#  'override',
#  'default',
#  'settings',
#  'box',
#  'build',
#  'process',
#  'variables',
#  'currently',
#  'used',
#  'cpus',
#  'disksize',
#  'memory',
#  'update',
#  'variable',
#  'headless',
#  'set',
#  'run',
#  'packer',
#  'headless',
#  'mode',
#  'set',
#  'headless',
#  'true',
#  'default',
#  'false',
#  'variable',
#  'update',
#  'used',
#  'perform',
#  'os',
#  'patch',
#  'management',
#  'default',
#  'not',
#  'apply',
#  'os',
#  'updates',
#  'default',
#  'update',
#  'true',
#  'latest',
#  'os',
#  'updates',
#  'applied',
#  'variable',
#  'packer',
#  'used',
#  'set',
#  'path',
#  'packer',
#  'binary',
#  'default',
#  'packer',
#  'variable',
#  'isopath',
#  'used',
#  'set',
#  'path',
#  'directory',
#  'os',
#  'install',
#  'images',
#  'override',
#  'commonly',
#  'used',
#  'speed',
#  'packer',
#  'builds',
#  'pointing',
#  'predownloaded',
#  'isos',
#  'instead',
#  'using',
#  'default',
#  'download',
#  'internet',
#  'urls',
#  'variables',
#  'sshusername',
#  'sshpassword',
#  'used',
#  'change',
#  'default',
#  'name',
#  'password',
#  'default',
#  'vagrantvagrant',
#  'respectively',
#  'variable',
#  'installvagrantkey',
#  'set',
#  'turn',
#  'installation',
#  'default',
#  'insecure',
#  'vagrant',
#  'key',
#  'image',
#  'used',
#  'outside',
#  'vagrant',
#  'set',
#  'installvagrantkey',
#  'false',
#  'default',
#  'true',
#  'variable',
#  'customscript',
#  'used',
#  'specify',
#  'custom',
#  'script',
#  'executed',
#  'add',
#  'scriptcustom',
#  'directory',
#  'content',
#  'ignored',
#  'git',
#  'default',
#  'customscriptsh',
#  'nothing',
#  'contributing',
#  '1',
#  'fork',
#  'clone',
#  'repo',
#  '2',
#  'create',
#  'new',
#  'branch',
#  'please',
#  'work',
#  'master',
#  'branch',
#  'directly',
#  '3',
#  'add',
#  'new',
#  'serverspechttpserverspecorg',
#  'batshttpsblogengineyardcom2014batstestcommandlinetools',
#  'tests',
#  'test',
#  'subtree',
#  'change',
#  'want',
#  'make',
#  'run',
#  'make',
#  'test',
#  'relevant',
#  'template',
#  'see',
#  'tests',
#  'fail',
#  'like',
#  'make',
#  'testvirtualboxubuntu2004',
#  '4',
#  'fix',
#  'stuff',
#  'use',
#  'make',
#  'ssh',
#  'interactively',
#  'test',
#  'box',
#  'like',
#  'make',
#  'sshvirtualboxubuntu2004',
#  '5',
#  'run',
#  'make',
#  'test',
#  'relevant',
#  'template',
#  'like',
#  'make',
#  'testvirtualboxubuntu2004',
#  'see',
#  'tests',
#  'pass',
#  'repeat',
#  'steps',
#  '35',
#  'done',
#  '6',
#  'update',
#  'readmemd',
#  'authors',
#  'reflect',
#  'changes',
#  '7',
#  'large',
#  'change',
#  'mind',
#  'still',
#  'preferred',
#  'split',
#  'small',
#  'commits',
#  'good',
#  'commit',
#  'messages',
#  'important',
#  'git',
#  'documentatproject',
#  'nice',
#  'guidelines',
#  'writing',
#  'descriptive',
#  'commit',
#  'messageshttpgitscmcombookch52htmlcommitguidelines',
#  '8',
#  'push',
#  'fork',
#  'submit',
#  'pull',
#  'request',
#  '9',
#  'submitted',
#  'full',
#  'make',
#  'test',
#  'run',
#  'performed',
#  'change',
#  'build',
#  'farm',
#  'notified',
#  'test',
#  'suite',
#  'fails',
#  'would',
#  'like',
#  'help',
#  'contact',
#  'moujanannawakecom',
#  'acknowledgments',
#  'parallelshttpwwwparallelscom',
#  'provided',
#  'business',
#  'edition',
#  'license',
#  'software',
#  'run',
#  'basebox',
#  'build',
#  'farm',
#  'img',
#  'srchttpwwwparallelscomfileadminimagescorporatebrandassetsimageslogoknockoutonredjpg',
#  'width80',
#  'smartystreetshttpwwwsmartystreetscom',
#  'provided',
#  'basebox',
#  'hosting',
#  'boxcutter',
#  'project',
#  'since',
#  '2015',
#  'thank',
#  'support',
#  'img',
#  'srchttpsd79i1fxsrar4tcloudfrontnetimagesbrandsmartystreets65887aa3png',
#  'width320',
#  'deepin',
#  'wine',
#  'ubuntu',
#  'debian',
#  'deepinwine',
#  'ubuntudebian',
#  'deepin',
#  'debian',
#  'giteegithubgitee',
#  'gpl1726509538qqcom',
#  'ubuntudebian',
#  '21819',
#  '1',
#  'bug',
#  'release',
#  'bash',
#  'wget',
#  'qo',
#  'httpsrawgithubusercontentcomwszqkzqkdeepinwineubuntumasteronlineinstallsh',
#  'bash',
#  'e',
#  'ubuntudebian',
#  'git',
#  'clone',
#  'httpsgithubcomwszqkzqkdeepinwineubuntugit',
#  'httpsgithubcomwszqkzqkdeepinwineubuntuarchivemasterzip',
#  'git',
#  'clone',
#  'httpsgiteecomwszqkzqkdeepinwineforubuntugit',
#  'releasesgithubhttpsgithubcomwszqkzqkdeepinwineubuntureleases',
#  'giteehttpsgiteecomwszqkzqkdeepinwineforubuntureleases',
#  'installsh',
#  'kdex',
#  'kdeinstallsh',
#  'deepinwine21822ubuntu',
#  'install2822sh',
#  '2',
#  'deepinwine',
#  'dpkg',
#  'deepin',
#  '1',
#  'qqhttppackagesdeepincomdeepinpoolnonfreeddeepincomqqim',
#  '2',
#  'timhttppackagesdeepincomdeepinpoolnonfreeddeepincomqqoffice',
#  '3',
#  'qqhttpspackagesdeepincomdeepinpoolnonfreeddeepincomqqimlight',
#  '4',
#  'httppackagesdeepincomdeepinpoolnonfreeddeepincomwechat',
#  'httpsgiteecomwszqkzqkdeepinwinecontainersforubunturawmasterdeepincomwechat26865deepin0i386deb',
#  '5',
#  'foxmailhttpspackagesdeepincomdeepinpoolnonfreeddeepincomfoxmail',
#  '6',
#  'httpspackagesdeepincomdeepinpoolnonfreeddeepincombaidupan',
#  '7',
#  '360httpspackagesdeepincomdeepinpoolnonfreeddeepincn360yasuo',
#  '8',
#  'winrarhttpspackagesdeepincomdeepinpoolnonfreeddeepincncomwinrar',
#  '9',
#  'httpspackagesdeepincomdeepinpoolnonfreeddeepincomthunderspeed',
#  '10',
#  'httpspackagesdeepincomdeepinpoolnonfreeddeepincomtaobaoaliclientqianniu',
#  'deepinwinehttpspackagesdeepincomdeepinpoolnonfreed',
#  '1',
#  'qqhttpsgiteecomwszqkzqkdeepinwinecontainersforubunturawmasterdeepincomqqim918deepin0i386deb',
#  '2',
#  'timhttpsgiteecomwszqkzqkdeepinwinecontainersforubunturawmasterdeepincomqqoffice200deepin4i386deb',
#  '3',
#  'qqhttpsgiteecomwszqkzqkdeepinwinecontainersforubunturawmasterdeepincomqqimlight7914308deepin8i386deb',
#  '4',
#  'httpsgiteecomwszqkzqkdeepinwinecontainersforubunturawmasterdeepincomwechat26865deepin0i386deb',
#  '5',
#  'foxmailhttpsgiteecomwszqkzqkdeepinwinecontainersforubunturawmasterdeepincomfoxmail72deepin3i386deb',
#  '6',
#  'httpsgiteecomwszqkzqkdeepinwinecontainersforubunturawmasterdeepincombaidupan573deepin0i386deb',
#  '7',
#  '360httpsgiteecomwszqkzqkdeepinwinecontainersforubunturawmasterdeepincn360yasuo4001060deepin3i386deb',
#  '8',
#  'winrarhttpsgiteecomwszqkzqkdeepinwinecontainersforubunturawmasterdeepincncomwinrar530deepin2i386deb',
#  '9',
#  'httpsgiteecomwszqkzqkdeepinwinecontainersforubunturawmasterdeepincomthunderspeed71035366deepin18i386deb',
#  '1kdekde',
#  'neonkubuntu',
#  '180418011802kde',
#  '2',
#  '3',
#  'ubuntu',
#  '1804',
#  'gnome',
#  'gnome',
#  'shell',
#  'topicons',
#  'plushttpsextensionsgnomeorgextension1031topicons',
#  '4tim',
#  'flash',
#  '1',
#  'installflashplayerppapiexe',
#  '2',
#  'deepinwinedeepintimdrivec',
#  'tim',
#  'wine',
#  'c',
#  '3',
#  'terminal',
#  'wineprefixdeepinwinedeepintim',
#  'deepinwine',
#  'cinstallflashplayerppapiexe',
#  'tim',
#  '5winecfg',
#  'wineprefixdeepinwine',
#  'deepinwine',
#  'winecfg',
#  '6',
#  'optdeepinwinetoolsrunsh',
#  'winecmd',
#  'winecmdlcallzhcnutf8',
#  'deepinwine',
#  '7',
#  'uninstallsh',
#  '8',
#  'wget',
#  'qo',
#  'httpsdeepinwineimdevsetupsh',
#  'sudo',
#  'sh',
#  '9',
#  'deepindeepinhttpsgiteecomwszqkzqkdeepinwinecontainersforubuntu',
#  'deepinwine',
#  '10wine',
#  'httpsblogdiqigancnpostswineglobalhotkeyproblemhtml',
#  '1',
#  'xdotool',
#  'shell',
#  'sudo',
#  'apt',
#  'install',
#  'noinstallrecommends',
#  'xdotool',
#  '2',
#  'xdotool',
#  'wine',
#  'xdotool',
#  'wine',
#  'openwechatsh',
#  'shell',
#  'binsh',
#  'wechatexectrlaltw',
#  'wechatwechatexe',
#  'xdotool',
#  'key',
#  'window',
#  'xdotool',
#  'search',
#  'limit',
#  '1',
#  'pid',
#  'pgrep',
#  'wechatexe',
#  'ctrlaltw',
#  'shell',
#  'chmod',
#  'x',
#  'openwechatsh',
#  '3',
#  'httpsimagesgiteecomuploadsimages202001170751414d17fab41442530png',
#  '4',
#  '11',
#  '1',
#  'shell',
#  'sudo',
#  'aptget',
#  'install',
#  'libjpeg62i386',
#  '1',
#  'fork',
#  '2',
#  'featxxx',
#  '3',
#  '4',
#  'pull',
#  'request',
#  '5',
#  '1',
#  'deepinhttpsbbsdeepinorgforumphpmodviewthreadtid40784extrapage3d1',
#  'dockerubuntuvncdesktop',
#  'docker',
#  'pullshttpsimgshieldsiodockerpullsdorowuubuntudesktoplxdevncsvghttpshubdockercomrdorowuubuntudesktoplxdevnc',
#  'docker',
#  'starshttpsimgshieldsiodockerstarsdorowuubuntudesktoplxdevncsvghttpshubdockercomrdorowuubuntudesktoplxdevnc',
#  'dockerubuntuvncdesktop',
#  'docker',
#  'image',
#  'provide',
#  'web',
#  'vnc',
#  'interface',
#  'access',
#  'ubuntu',
#  'lxdelxqt',
#  'desktop',
#  'environment',
#  'import',
#  'toc',
#  'cmdtoc',
#  'depthfrom2',
#  'depthto2',
#  'orderedlistfalse',
#  'codechunkoutput',
#  'quick',
#  'startquickstart',
#  'vnc',
#  'viewervncviewer',
#  'http',
#  'base',
#  'authenticationhttpbaseauthentication',
#  'sslssl',
#  'screen',
#  'resolutionscreenresolution',
#  'default',
#  'desktop',
#  'userdefaultdesktopuser',
#  'deploy',
#  'subdirectory',
#  'relative',
#  'url',
#  'rootdeploytoasubdirectoryrelativeurlroot',
#  'sound',
#  'preview',
#  'version',
#  'linux',
#  'onlysoundpreviewversionandlinuxonly',
#  'generate',
#  'dockerfile',
#  'jinja',
#  'templategeneratedockerfilefromjinjatemplate',
#  'troubleshooting',
#  'faqtroubleshootingandfaq',
#  'licenselicense',
#  'codechunkoutput',
#  'quick',
#  'start',
#  'run',
#  'docker',
#  'container',
#  'access',
#  'port',
#  '6080',
#  'shell',
#  'docker',
#  'run',
#  'p',
#  '608080',
#  'v',
#  'devshmdevshm',
#  'dorowuubuntudesktoplxdevnc',
#  'browse',
#  'http1270016080',
#  'img',
#  'srchttpsrawgithubcomfcwudockerubuntuvncdesktopmasterscreenshotslxdepngv1',
#  'width700',
#  'ubuntu',
#  'flavors',
#  'choose',
#  'favorite',
#  'ubuntu',
#  'version',
#  'tagshttpshubdockercomrdorowuubuntudesktoplxdevnctags',
#  'focal',
#  'ubuntu',
#  '2004',
#  'latest',
#  'focallxqt',
#  'ubuntu',
#  '2004',
#  'lxqt',
#  'bionic',
#  'ubuntu',
#  '1804',
#  'bioniclxqt',
#  'ubuntu',
#  '1804',
#  'lxqt',
#  'xenial',
#  'ubuntu',
#  '1604',
#  'deprecated',
#  'trusty',
#  'ubuntu',
#  '1404',
#  'deprecated',
#  'vnc',
#  'viewer',
#  'forward',
#  'vnc',
#  'service',
#  'port',
#  '5900',
#  'host',
#  'shell',
#  'docker',
#  'run',
#  'p',
#  '608080',
#  'p',
#  '59005900',
#  'v',
#  'devshmdevshm',
#  'dorowuubuntudesktoplxdevnc',
#  'open',
#  'vnc',
#  'viewer',
#  'connect',
#  'port',
#  '5900',
#  'would',
#  'like',
#  'protect',
#  'vnc',
#  'service',
#  'password',
#  'set',
#  'environment',
#  'variable',
#  'vncpassword',
#  'example',
#  'shell',
#  'docker',
#  'run',
#  'p',
#  '608080',
#  'p',
#  '59005900',
#  'e',
#  'vncpasswordmypassword',
#  'v',
#  'devshmdevshm',
#  'dorowuubuntudesktoplxdevnc',
#  'prompt',
#  'ask',
#  'password',
#  'either',
#  'browser',
#  'vnc',
#  'viewer',
#  'http',
#  'base',
#  'authentication',
#  'image',
#  'provides',
#  'base',
#  'access',
#  'authentication',
#  'http',
#  'via',
#  'httppassword',
#  'shell',
#  'docker',
#  'run',
#  'p',
#  '608080',
#  'e',
#  'httppasswordmypassword',
#  'v',
#  'devshmdevshm',
#  ...]

# %% [markdown]
# ### These should be the top 40 words we include in stopwords for our clean/prep:

# %%
main_count = pd.Series(master_corpus_list)
main_count.value_counts().nlargest(60)
# Out:
# install          8850
# sudo             6609
# use              6596
# not              5945
# run              5938
# file             5441
# linux            5206
# 3                5096
# 1                4662
# script           4508
# ubuntu           4468
# default          4276
# build            4163
# system           4040
# using            3940
# docker           3792
# bash             3732
# make             3693
# kernel           3591
# version          3562
# packages         3527
# package          3516
# image            3441
# debian           3413
# server           3295
# set              3281
# files            3208
# 6                3036
# arch             2827
# configuration    2790
# installation     2717
# user             2708
# also             2685
# update           2610
# see              2605
# used             2590
# need             2582
# 2                2561
# git              2559
# command          2536
# add              2473
# following        2403
# directory        2379
# no               2322
# new              2312
# want             2260
# create           2248
# installed        2244
# e                2236
# name             2196
# support          2085
# root             1981
# running          1941
# one              1890
# p                1882
# like             1873
# environment      1861
# example          1826
# repository       1807
# source           1748
# dtype: int64

# %%
ADDITIONAL_STOPWORDS=[
    'sudo', 'use', 'not', 'run',
    'file', 'linux', 3 ,'3', 1 ,'1', 'script', 'ubuntu', 
    'default', 'build', 'system', 'using', 
    'docker', 'make', 'kernel',
    'version','packages', 'package','image',
    'debian', 'server', 'set', 'files',6, 
    'arch', 'configuration', 'installation',
    'user', 'also', 'update', 'see', 'used',
    'need', 2, '2', '4', '0', 'git', 'command', 'add',
    'following', 'directory', 'no', 'new',
    'want', 'create', 'installed', 'e', 'name', 
    'support', 'root', 'running', 'one', 'p',
    'like', 'environment', 'example', 'repository',
    'source', 'archlinux','ubuntu','debian','arch'
]

# %%
#applying clean and stemming
def clean_data(text):
    ps = nltk.porter.PorterStemmer()
    stopwords = nltk.corpus.stopwords.words('english') + ADDITIONAL_STOPWORDS
    text = (unicodedata.normalize('NFKD', text)
             .encode('ascii', 'ignore')
             .decode('utf-8', 'ignore')
             .lower())
    words = re.sub(r'[\(<\"]?http.*[\)>\"\s]', ' ', text).split()
    words = [re.sub(r'[^\w\s]', '', text) for text in words]
    try:
        while True:
            words.remove('')
    except ValueError:
        pass
    
    return [word for word in words if word not in stopwords]

# %%
#creating a new list of top mentioned words:
main_list = clean_data(master_corpus)
main_list
# Out:
# ['dockerfile',
#  'contains',
#  'dockerfile',
#  'base',
#  'ubuntu1404',
#  'install',
#  'download',
#  'automated',
#  'alternatively',
#  'dockerfile',
#  'tdockerfileubuntu',
#  'githubcomdockerfileubuntu',
#  'usage',
#  'rm',
#  'dockerfileubuntu',
#  'packer',
#  'templates',
#  'written',
#  'legacy',
#  'json',
#  'overview',
#  'contains',
#  'packer',
#  'current',
#  'boxes',
#  'longer',
#  'provide',
#  'prebuilt',
#  'binaries',
#  'templates',
#  'building',
#  'vagrant',
#  'boxes',
#  'packer',
#  'boxes',
#  'virtualbox',
#  'vmware',
#  'fusion',
#  'parallels',
#  'parallels',
#  'requires',
#  'parallels',
#  'virtualization',
#  'sdk',
#  'mac',
#  'additional',
#  'prerequisite',
#  'json',
#  'containing',
#  'variables',
#  'specific',
#  'versions',
#  'tell',
#  'packer',
#  'specific',
#  'variable',
#  'via',
#  'varfile',
#  'line',
#  'option',
#  'override',
#  'options',
#  'core',
#  'ubuntujson',
#  'packer',
#  'template',
#  'builds',
#  '2004',
#  '2004',
#  'packer',
#  'varfileubuntu2004json',
#  'ubuntujson',
#  'boxes',
#  'specific',
#  'desktop',
#  'virtualization',
#  'platform',
#  'parameter',
#  '2004',
#  'virtualbox',
#  'packer',
#  'onlyvirtualboxiso',
#  'varfileubuntu2004json',
#  'ubuntujson',
#  'boxcutter',
#  'templates',
#  'currently',
#  'desktop',
#  'virtualization',
#  'strings',
#  'parallelsiso',
#  'parallels',
#  'virtualboxiso',
#  'virtualbox',
#  'vmwareiso',
#  'vmware',
#  'fusion',
#  'building',
#  'vagrant',
#  'boxes',
#  'box',
#  'weve',
#  'provided',
#  'wrapper',
#  'binbox',
#  'ease',
#  'alternatively',
#  '2004',
#  'providers',
#  'binbox',
#  'ubuntu2004',
#  '2004',
#  'virtualbox',
#  'binbox',
#  'ubuntu2004',
#  'virtualbox',
#  'building',
#  'vagrant',
#  'boxes',
#  'makefile',
#  'gnu',
#  'makefile',
#  'drives',
#  'complete',
#  'basebox',
#  'creation',
#  'pipeline',
#  'stages',
#  'basebox',
#  'box',
#  'assure',
#  'verify',
#  'basebox',
#  'box',
#  'produced',
#  'function',
#  'correctly',
#  'deliver',
#  'upload',
#  'box',
#  'artifactory',
#  'pipeline',
#  'driven',
#  'via',
#  'targets',
#  'making',
#  'easy',
#  'include',
#  'favourite',
#  'ci',
#  'tool',
#  'available',
#  'box',
#  'types',
#  'assure',
#  'tests',
#  'boxes',
#  'deliver',
#  'upload',
#  'box',
#  'artifacts',
#  'clean',
#  'clean',
#  'detritus',
#  'proxy',
#  'settings',
#  'templates',
#  'respect',
#  'network',
#  'proxy',
#  'variables',
#  'forward',
#  'virtual',
#  'machine',
#  'box',
#  'creation',
#  'process',
#  'proxy',
#  'ftpproxy',
#  'rsyncproxy',
#  'noproxy',
#  'tests',
#  'automated',
#  'tests',
#  'written',
#  'serverspec',
#  'vagrantserverspec',
#  'plugin',
#  'vagrant',
#  'plugin',
#  'install',
#  'vagrantserverspec',
#  'binbox',
#  'subcommands',
#  'automated',
#  'tests',
#  'performing',
#  'exploratory',
#  'testing',
#  'binbox',
#  'test',
#  'subcommand',
#  'automated',
#  'serverspec',
#  'tests',
#  'execute',
#  'tests',
#  '2004',
#  'box',
#  'virtualbox',
#  'binbox',
#  'test',
#  'ubuntu2004',
#  'virtualbox',
#  'similarly',
#  'perform',
#  'exploratory',
#  'testing',
#  'virtualbox',
#  'via',
#  'ssh',
#  'binbox',
#  'ssh',
#  'ubuntu2004',
#  'virtualbox',
#  'variable',
#  'overrides',
#  'several',
#  'variables',
#  'override',
#  'settings',
#  'box',
#  'process',
#  'variables',
#  'currently',
#  'cpus',
#  'disksize',
#  'memory',
#  'variable',
#  'headless',
#  'packer',
#  'headless',
#  'mode',
#  'headless',
#  'true',
#  'false',
#  'variable',
#  'perform',
#  'os',
#  'patch',
#  'management',
#  'apply',
#  'os',
#  'updates',
#  'true',
#  'latest',
#  'os',
#  'updates',
#  'applied',
#  'variable',
#  'packer',
#  'path',
#  'packer',
#  'binary',
#  'packer',
#  'variable',
#  'isopath',
#  'path',
#  'os',
#  'install',
#  'images',
#  'override',
#  'commonly',
#  'speed',
#  'packer',
#  'builds',
#  'pointing',
#  'predownloaded',
#  'isos',
#  'instead',
#  'download',
#  'internet',
#  'urls',
#  'variables',
#  'sshusername',
#  'sshpassword',
#  'change',
#  'password',
#  'vagrantvagrant',
#  'respectively',
#  'variable',
#  'installvagrantkey',
#  'turn',
#  'insecure',
#  'vagrant',
#  'key',
#  'outside',
#  'vagrant',
#  'installvagrantkey',
#  'false',
#  'true',
#  'variable',
#  'customscript',
#  'specify',
#  'custom',
#  'executed',
#  'scriptcustom',
#  'content',
#  'ignored',
#  'customscriptsh',
#  'nothing',
#  'contributing',
#  'fork',
#  'clone',
#  'repo',
#  'branch',
#  'please',
#  'dont',
#  'work',
#  'master',
#  'branch',
#  'directly',
#  'serverspec',
#  'fix',
#  'stuff',
#  'ssh',
#  'interactively',
#  'test',
#  'box',
#  'sshvirtualboxubuntu2004',
#  '5',
#  'test',
#  'relevant',
#  'template',
#  'testvirtualboxubuntu2004',
#  'tests',
#  'pass',
#  'repeat',
#  'steps',
#  '35',
#  'done',
#  '6',
#  'readmemd',
#  'authors',
#  'reflect',
#  'changes',
#  '7',
#  'large',
#  'change',
#  'mind',
#  'still',
#  'preferred',
#  'split',
#  'small',
#  'commits',
#  'good',
#  'commit',
#  'messages',
#  'important',
#  'documentatproject',
#  'nice',
#  'guidelines',
#  'writing',
#  'descriptive',
#  'commit',
#  'messages',
#  '8',
#  'push',
#  'fork',
#  'submit',
#  'pull',
#  'request',
#  '9',
#  'submitted',
#  'full',
#  'test',
#  'performed',
#  'change',
#  'farm',
#  'notified',
#  'test',
#  'suite',
#  'fails',
#  'would',
#  'help',
#  'contact',
#  'moujanannawakecom',
#  'acknowledgments',
#  'parallels',
#  'software',
#  'basebox',
#  'farm',
#  'img',
#  'src',
#  'smartystreets',
#  'img',
#  'src',
#  'deepin',
#  'wine',
#  'deepinwine',
#  'ubuntudebian',
#  'deepin',
#  'giteegithubgitee',
#  'gpl1726509538qqcom',
#  'ubuntudebian',
#  '21819',
#  'bug',
#  'release',
#  'bash',
#  'wget',
#  'qo',
#  'ubuntudebian',
#  'clone',
#  'clone',
#  'releasesgithub',
#  'gitee',
#  'installsh',
#  'kdex',
#  'kdeinstallsh',
#  'deepinwine21822ubuntu',
#  'install2822sh',
#  'deepinwine',
#  'dpkg',
#  'deepin',
#  'qq',
#  'tim',
#  'qq',
#  '5',
#  'foxmail',
#  '6',
#  '7',
#  '360',
#  '8',
#  'winrar',
#  '9',
#  '10',
#  'deepinwine',
#  'qq',
#  'tim',
#  'qq',
#  '5',
#  'foxmail',
#  '6',
#  '7',
#  '360',
#  '8',
#  'winrar',
#  '9',
#  '1kdekde',
#  'neonkubuntu',
#  '180418011802kde',
#  '1804',
#  'gnome',
#  'gnome',
#  'shell',
#  'topicons',
#  'plus',
#  '4tim',
#  'flash',
#  'installflashplayerppapiexe',
#  'deepinwinedeepintimdrivec',
#  'tim',
#  'wine',
#  'c',
#  'terminal',
#  'wineprefixdeepinwinedeepintim',
#  'deepinwine',
#  'cinstallflashplayerppapiexe',
#  'tim',
#  '5winecfg',
#  'wineprefixdeepinwine',
#  'deepinwine',
#  'winecfg',
#  '6',
#  'optdeepinwinetoolsrunsh',
#  'winecmd',
#  'winecmdlcallzhcnutf8',
#  'deepinwine',
#  '7',
#  'uninstallsh',
#  '8',
#  'wget',
#  'qo',
#  '9',
#  'deepindeepin',
#  'deepinwine',
#  '10wine',
#  'xdotool',
#  'shell',
#  'apt',
#  'install',
#  'noinstallrecommends',
#  'xdotool',
#  'xdotool',
#  'wine',
#  'xdotool',
#  'wine',
#  'openwechatsh',
#  'shell',
#  'binsh',
#  'wechatexectrlaltw',
#  'wechatwechatexe',
#  'xdotool',
#  'key',
#  'window',
#  'xdotool',
#  'search',
#  'limit',
#  'pid',
#  'pgrep',
#  'wechatexe',
#  'ctrlaltw',
#  'shell',
#  'chmod',
#  'x',
#  'openwechatsh',
#  '11',
#  'shell',
#  'aptget',
#  'install',
#  'libjpeg62i386',
#  'fork',
#  'featxxx',
#  'pull',
#  'request',
#  '5',
#  'deepin',
#  'dockerubuntuvncdesktop',
#  'pulls',
#  'stars',
#  'dockerubuntuvncdesktop',
#  'provide',
#  'web',
#  'vnc',
#  'interface',
#  'access',
#  'lxdelxqt',
#  'desktop',
#  'import',
#  'toc',
#  'cmdtoc',
#  'depthfrom2',
#  'depthto2',
#  'orderedlistfalse',
#  'codechunkoutput',
#  'quick',
#  'startquickstart',
#  'vnc',
#  'viewervncviewer',
#  'sslssl',
#  'screen',
#  'resolutionscreenresolution',
#  'desktop',
#  'userdefaultdesktopuser',
#  'deploy',
#  'subdirectory',
#  'relative',
#  'url',
#  'rootdeploytoasubdirectoryrelativeurlroot',
#  'sound',
#  'preview',
#  'onlysoundpreviewversionandlinuxonly',
#  'generate',
#  'dockerfile',
#  'jinja',
#  'templategeneratedockerfilefromjinjatemplate',
#  'troubleshooting',
#  'faqtroubleshootingandfaq',
#  'licenselicense',
#  'codechunkoutput',
#  'quick',
#  'start',
#  'container',
#  'access',
#  'port',
#  '6080',
#  'shell',
#  '608080',
#  'v',
#  'devshmdevshm',
#  'dorowuubuntudesktoplxdevnc',
#  'browse',
#  'img',
#  'src',
#  'flavors',
#  'choose',
#  'favorite',
#  'tags',
#  'focal',
#  '2004',
#  'latest',
#  'focallxqt',
#  '2004',
#  'lxqt',
#  'bionic',
#  '1804',
#  'bioniclxqt',
#  '1804',
#  'lxqt',
#  'xenial',
#  '1604',
#  'deprecated',
#  'trusty',
#  '1404',
#  'deprecated',
#  'vnc',
#  'viewer',
#  'forward',
#  'vnc',
#  'service',
#  'port',
#  '5900',
#  'host',
#  'shell',
#  '608080',
#  '59005900',
#  'v',
#  'devshmdevshm',
#  'dorowuubuntudesktoplxdevnc',
#  'open',
#  'vnc',
#  'viewer',
#  'connect',
#  'port',
#  '5900',
#  'would',
#  'protect',
#  'vnc',
#  'service',
#  'password',
#  'variable',
#  'vncpassword',
#  'shell',
#  '608080',
#  '59005900',
#  'vncpasswordmypassword',
#  'v',
#  'devshmdevshm',
#  'dorowuubuntudesktoplxdevnc',
#  'prompt',
#  'ask',
#  'password',
#  'either',
#  'browser',
#  'vnc',
#  'viewer',
#  'provides',
#  'base',
#  'access',
#  'authentication',
#  'shell',
#  '608080',
#  'ssl',
#  'connect',
#  'ssl',
#  'generate',
#  'self',
#  'signed',
#  'ssl',
#  'certificate',
#  'first',
#  'dont',
#  'shell',
#  'mkdir',
#  'ssl',
#  'openssl',
#  'req',
#  'x509',
#  'nodes',
#  'days',
#  '365',
#  'newkey',
#  'rsa2048',
#  'keyout',
#  'sslnginxkey',
#  'sslnginxcrt',
#  'specify',
#  'ssl',
#  'port',
#  'sslport',
#  'certificate',
#  'path',
#  'etcnginxssl',
#  'forward',
#  '6081',
#  'shell',
#  '6081443',
#  'sslport443',
#  'v',
#  'pwdssletcnginxssl',
#  'v',
#  'devshmdevshm',
#  'dorowuubuntudesktoplxdevnc',
#  'screen',
#  'resolution',
#  'resolution',
#  'virtual',
#  'desktop',
#  'adapts',
#  'browser',
#  'window',
#  'size',
#  'first',
#  'connecting',
#  'may',
#  'choose',
#  'fixed',
#  'resolution',
#  'passing',
#  'resolution',
#  'variable',
#  'shell',
#  '608080',
#  'resolution1920x1080',
#  'v',
#  'devshmdevshm',
#  'dorowuubuntudesktoplxdevnc',
#  'desktop',
#  'may',
#  'change',
#  'password',
#  'respectively',
#  'password',
#  'variable',
#  'shell',
#  '608080',
#  'userdoro',
#  'passwordpassword',
#  'v',
#  'devshmdevshm',
#  'dorowuubuntudesktoplxdevnc',
#  'deploy',
#  'subdirectory',
#  'relative',
#  'url',
#  'may',
#  'deploy',
#  'application',
#  'subdirectory',
#  'someprefix',
#  'access',
#  'application',
#  'shell',
#  '608080',
#  'relativeurlrootsomeprefix',
#  'dorowuubuntudesktoplxdevnc',
#  'note',
#  'variable',
#  'leading',
#  'trailing',
#  'splash',
#  'sound',
#  'preview',
#  'works',
#  'first',
#  'insert',
#  'module',
#  'sndaloop',
#  'specify',
#  'index',
#  'sound',
#  'loop',
#  'device',
#  'shell',
#  'modprobe',
#  'sndaloop',
#  'index2',
#  'start',
#  'container',
#  'shell',
#  'rm',
#  '608080',
#  'device',
#  'devsnd',
#  'alsadevhw20',
#  'dorowuubuntudesktoplxdevnc',
#  'device',
#  'devsnd',
#  'alsadevhw20',
#  'means',
#  'grant',
#  'sound',
#  'device',
#  'container',
#  'basic',
#  'asla',
#  'config',
#  'card',
#  'launch',
#  'browser',
#  'url',
#  'screen',
#  'capture',
#  'operations',
#  'turn',
#  'sound',
#  'end',
#  'video',
#  'demo',
#  'video',
#  'generate',
#  'dockerfile',
#  'jinja',
#  'template',
#  'warning',
#  'deprecated',
#  'dockerfile',
#  'generated',
#  'template',
#  'amd64',
#  'armhf',
#  'flavor',
#  'refer',
#  'flavorflavoryml',
#  'base',
#  'desktop',
#  'desktop',
#  'flavor',
#  'addonpackage',
#  'flavor',
#  'dockerfile',
#  'regenerate',
#  'exist',
#  'may',
#  'force',
#  'regenerate',
#  'removing',
#  'clean',
#  'troubleshooting',
#  'faq',
#  'boot2docker',
#  'connection',
#  'issue',
#  'multilanguage',
#  'supports',
#  'autostart',
#  'x11vnc',
#  'argumentsmultiptr',
#  '5',
#  'firefoxchrome',
#  'crash',
#  'devshm',
#  '6',
#  'resize',
#  'display',
#  'size',
#  'without',
#  'destroying',
#  'container',
#  'license',
#  'license',
#  'details',
#  'i386',
#  'buildimagesh',
#  '32bitubuntu1604',
#  'deprecated',
#  'cookbook',
#  'deprecated',
#  'instead',
#  'aptrepository',
#  'locale',
#  'resources',
#  'built',
#  'chef',
#  'infra',
#  'client',
#  'managing',
#  'systems',
#  'cookbook',
#  'status',
#  'sets',
#  'apt',
#  'sources',
#  'manages',
#  'locale',
#  'settings',
#  'requirements',
#  'platforms',
#  'chef',
#  'chef',
#  '13',
#  'cookbooks',
#  'none',
#  'attributes',
#  'attributesdefaultrb',
#  'values',
#  'nodeubuntuarchiveurl',
#  'archived',
#  'repo',
#  'url',
#  'nodeubuntusecurityurl',
#  'security',
#  'repo',
#  'url',
#  'nodeubuntuincludesourcepackages',
#  'apt',
#  'sources',
#  'defaults',
#  'true',
#  'nodeubuntuarchitectures',
#  'optional',
#  'array',
#  'architectures',
#  'download',
#  'repos',
#  'defaults',
#  'nil',
#  'archs',
#  'nodeubuntucomponents',
#  'components',
#  'defaults',
#  'main',
#  'restricted',
#  'universe',
#  'multiverse',
#  'nodeubuntulocale',
#  'locale',
#  'os',
#  'nodeubuntucodename',
#  'codename',
#  'defaults',
#  'nodelsbcodename',
#  'eg',
#  'precise',
#  'recipes',
#  'includes',
#  'apt',
#  'recipe',
#  'ensure',
#  'cache',
#  'updated',
#  'manages',
#  'etcaptsourceslist',
#  'nodes',
#  'platform',
#  'code',
#  'template',
#  'adds',
#  'sources',
#  'main',
#  'restricted',
#  'universe',
#  'multiverse',
#  'usage',
#  'include',
#  'recipeubuntu',
#  'systems',
#  'manage',
#  'sourceslist',
#  'currently',
#  'template',
#  'enables',
#  'main',
#  'restricted',
#  'universe',
#  'multiverse',
#  'nodes',
#  'codename',
#  'eg',
#  'lucid',
#  'natty',
#  'etc',
#  'roadmap',
#  'license',
#  'authors',
#  'author',
#  'cookbook',
#  'engineering',
#  'team',
#  'cookbookschefiomailtocookbookschefio',
#  'copyright',
#  '20082019',
#  'chef',
#  'software',
#  'inc',
#  'licensed',
#  'apache',
#  'license',
#  '20',
#  'license',
#  'may',
#  'except',
#  'compliance',
#  'license',
#  'may',
#  'obtain',
#  'copy',
#  'license',
#  'unless',
#  'required',
#  'applicable',
#  'law',
#  'agreed',
#  'writing',
#  'software',
#  'distributed',
#  'license',
#  'distributed',
#  'basis',
#  'without',
#  ...]

# %%
#creating new series
main_list_count = pd.Series(main_list)

# %% [markdown]
# ### Top words of Full corpus, after clean:

# %%
#creating new top words list:
main_list_count.value_counts().nlargest(50)
# Out:
# install      8654
# bash         3506
# boot         1676
# cd           1663
# please       1662
# may          1659
# start        1617
# de           1606
# work         1605
# download     1569
# available    1556
# container    1534
# shell        1529
# ensure       1524
# time         1495
# list         1494
# get          1487
# note         1478
# apt          1471
# scripts      1455
# aptget       1448
# x            1445
# project      1440
# license      1416
# config       1397
# ssh          1394
# software     1383
# sh           1364
# first        1361
# code         1354
# setup        1349
# key          1340
# change       1337
# password     1315
# clone        1295
# service      1294
# via          1284
# pacman       1280
# check        1275
# options      1274
# host         1271
# os           1261
# desktop      1227
# option       1206
# network      1198
# enable       1161
# video        1154
# device       1150
# without      1145
# library      1139
# dtype: int64

# %%
#finding all shell readmes:
shell_readme =' '.join(master_df[master_df['language'] == 'Shell'].clean_readme)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/d3/11nygz6126ndxvtrp12687680000gn/T/ipykernel_20454/275557440.py in <module>
#       1 #finding all shell readmes:
# ----> 2 shell_readme =' '.join(master_df[master_df['language'] == 'Shell'].clean_readme)
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'clean_readme'

# %%
#renaming to shell words and cleaning data:
shell_words=clean_data(shell_readme)

# %%
#finding all python readmes:
python_readme =' '.join(master_df[master_df['language'] == 'Python'].clean_readme)

# %%
#renaming to python words and cleaning data:
python_words=clean_data(python_readme)

# %%
#finding all C readmes:
C_readme =' '.join(master_df[master_df['language'] == 'C'].clean_readme)

# %%
#renaming to C words and cleaning data:
C_words=clean_data(C_readme)

# %%
#finding all dockerfile readmes:
dockerfile_readme =' '.join(master_df[master_df['language'] == 'Dockerfile'].clean_readme)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/d3/11nygz6126ndxvtrp12687680000gn/T/ipykernel_20454/2876884164.py in <module>
#       1 #finding all dockerfile readmes:
# ----> 2 dockerfile_readme =' '.join(master_df[master_df['language'] == 'Dockerfile'].clean_readme)
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'clean_readme'

# %%
#renaming to dockerfile words and cleaning data:
dockerfile_words=clean_data(dockerfile_readme)

# %%
#creating series with frequencies by putting the clean_readme strings
#as series (but use split to split up words into a list)

shell_freq = pd.Series(shell_words.split()).value_counts()
python_freq = pd.Series(python_words.split()).value_counts()
dockerfile_freq = pd.Series(dockerfile_words.split()).value_counts()
C_freq = pd.Series(C_words.split()).value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/d3/11nygz6126ndxvtrp12687680000gn/T/ipykernel_20454/1691822659.py in <module>
#       4 shell_freq = pd.Series(shell_words.split()).value_counts()
#       5 python_freq = pd.Series(python_words.split()).value_counts()
# ----> 6 dockerfile_freq = pd.Series(dockerfile_words.split()).value_counts()
#       7 C_freq = pd.Series(C_words.split()).value_counts()
#
# AttributeError: 'list' object has no attribute 'split'

# %%
#combining frequencies into dataframes:
word_counts = (pd.concat([shell_freq, python_freq, C_freq, dockerfile_freq ], axis=1, sort=True)
              .set_axis(['shell','python','C','dockerfile'], axis=1, inplace=False)
              .fillna(0)
              .apply(lambda s: s.astype(int)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/d3/11nygz6126ndxvtrp12687680000gn/T/ipykernel_20454/3980730109.py in <module>
#       1 #combining frequencies into dataframes:
# ----> 2 word_counts = (pd.concat([shell_freq, python_freq, C_freq, dockerfile_freq ], axis=1, sort=True)
#       3               .set_axis(['shell','python','C','dockerfile'], axis=1, inplace=False)
#       4               .fillna(0)
#       5               .apply(lambda s: s.astype(int)))
#
# NameError: name 'C_freq' is not defined

# %%
word_counts
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/d3/11nygz6126ndxvtrp12687680000gn/T/ipykernel_20454/1599599241.py in <module>
# ----> 1 word_counts
#
# NameError: name 'word_counts' is not defined

# %% [markdown]
# ### What are the most occuring words across these languages?

# %%
word_counts.sort_values(by='shell', ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/d3/11nygz6126ndxvtrp12687680000gn/T/ipykernel_20454/1100361335.py in <module>
# ----> 1 word_counts.sort_values(by='shell', ascending=False).head(10)
#
# NameError: name 'word_counts' is not defined

# %% [markdown]
# ## How long is an average ReadMe across languages?

# %%
#creating a column that gives the lenght of the readme_contents after clean_data function
master_df['length_of_readme'] = master_df['readme_contents'].apply(lambda r : len(clean_data(r)))
# Out:
# /var/folders/d3/11nygz6126ndxvtrp12687680000gn/T/ipykernel_20454/4054679634.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   master_df['length_of_readme'] = master_df['readme_contents'].apply(lambda r : len(clean_data(r)))

# %%
master_df.head()
# Out:
#                              repo language  \
# 0               dockerfile/ubuntu    Shell
# 1                boxcutter/ubuntu    Shell
# 2     wszqkzqk/deepin-wine-ubuntu        C
# 3  fcwu/docker-ubuntu-vnc-desktop     HTML
# 4             docker-32bit/ubuntu    Shell
#
#                                      readme_contents  distro  length_of_readme
# 0  ## Ubuntu Dockerfile\n\n\nThis repository cont...  ubuntu                15
# 1  # Packer templates for Ubuntu written in legac...  ubuntu               382
# 2  # Deepin wine for Ubuntu and Debian\n\n## 一、项目...  ubuntu               130
# 3  # docker-ubuntu-vnc-desktop\n\n[![Docker Pulls...  ubuntu               325
# 4  ubuntu\n======\n\nBuild a docker image for ubu...  ubuntu                 3

# %%
plt.figure(figsize=(18, 12))
sns.barplot(data = master_df.groupby('language').mean().reset_index().sort_values('length_of_readme', ascending=False), x = 'length_of_readme', y='language')
plt.title('Average Readme length by Language')
plt.show()

# %%
## Number of Unique words:
main_corpus_series = pd.Series(master_corpus_list)
pd.Series(master_corpus_list).nunique()
# Out:
# 117986

# %% [markdown]
# ### Most common bigrams:

# %%
master_bigrams = (pd.Series(nltk.ngrams(main_corpus_series, 2)).value_counts().head(20))
master_bigrams
# Out:
# (arch, linux)            1778
# (3, 3)                   1096
# (git, clone)              861
# (aptget, install)         859
# (sudo, aptget)            833
# (sudo, apt)               812
# (6, 6)                    744
# (apt, install)            692
# (make, sure)              691
# (docker, run)             673
# (math, kernel)            644
# (kernel, library)         644
# (intelr, math)            640
# (3, 6)                    538
# (accept, poster)          532
# (6, 3)                    529
# (ubuntu, server)          504
# (configuration, file)     476
# (bash, sudo)              462
# (141, reject)             455
# dtype: int64

# %%
##realized I forgot to rename my cleaned df...will need to go back up and find that...

# %% [markdown]
# __________________________________

# %% [markdown]
# ## Trying out the new stopwords:

# %%
#calling in master_df:
master_df = pd.read_csv('master_list.csv')

# %%
master_df
# Out:
#                                 repo language  \
# 0                  dockerfile/ubuntu    Shell
# 1                   boxcutter/ubuntu    Shell
# 2        wszqkzqk/deepin-wine-ubuntu        C
# 3     fcwu/docker-ubuntu-vnc-desktop     HTML
# 4                docker-32bit/ubuntu    Shell
# ...                              ...      ...
# 3295        gmas/home-router-ansible     Ruby
# 3296                  Voltasalt/tial    Shell
# 3297           Caesim404/sikulix-git    Shell
# 3298          danboid/ZALARM-install      NaN
# 3299               BiteDasher/pacadd    Shell
#
#                                         readme_contents  distro
# 0     ## Ubuntu Dockerfile\n\n\nThis repository cont...  ubuntu
# 1     # Packer templates for Ubuntu written in legac...  ubuntu
# 2     # Deepin wine for Ubuntu and Debian\n\n## 一、项目...  ubuntu
# 3     # docker-ubuntu-vnc-desktop\n\n[![Docker Pulls...  ubuntu
# 4     ubuntu\n======\n\nBuild a docker image for ubu...  ubuntu
# ...                                                 ...     ...
# 3295  # home-router-ansible\nAnsible scripts for set...    arch
# 3296      # tial\nTwitch Installs Arch Linux: Scripts\n    arch
# 3297                                                NaN    arch
# 3298  # Installing Arch Linux ARM (ALARM) on the SHA...    arch
# 3299  # pacadd\nA simple tool for managing repositor...    arch
#
# [3300 rows x 4 columns]

# %%
#using drop null function:
master_df = constants_prepare.drop_nulls(master_df)

# %%
#pulling in new columns:
master_df = constants_prepare.adding_columns(master_df)
master_df
